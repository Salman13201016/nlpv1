# %%
# !pip install bltk
# Out:
# Collecting bltk
#   Downloading bltk-1.2.tar.gz (17.4 MB)
# Requirement already satisfied: sklearn>=0.0 in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from bltk) (0.0)
# Requirement already satisfied: six>=1.13.0 in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from bltk) (1.16.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from bltk) (1.7.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from bltk) (1.0)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from bltk) (1.22.4)
# Requirement already satisfied: nltk>=3.4.5 in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from bltk) (3.8.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\acer\appdata\roaming\python\python39\site-packages (from bltk) (1.2.0)
# Requirement already satisfied: certifi>=2019.11.28 in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from bltk) (2021.10.8)
# Requirement already satisfied: click in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from nltk>=3.4.5->bltk) (8.0.1)
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from nltk>=3.4.5->bltk) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from nltk>=3.4.5->bltk) (2022.10.31)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from scikit-learn>=0.21.3->bltk) (3.0.0)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\envs\ml\lib\site-packages (from click->nltk>=3.4.5->bltk) (0.4.4)
# Building wheels for collected packages: bltk
#   Building wheel for bltk (setup.py): started
#   Building wheel for bltk (setup.py): finished with status 'done'
#   Created wheel for bltk: filename=bltk-1.2-py3-none-any.whl size=17432541 sha256=c6a2c274563fd4f3858fb50af3787f2fb2045a2c802a63cda5817eca3cde3fd2
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\40\95\27\80bfbeb60364f00de71ea3570cb9b76ab17c8e8ab944c2d81b
# Successfully built bltk
# Installing collected packages: bltk
# Successfully installed bltk-1.2

# %% [markdown]
# ##**Importing Libraries**

# %%
from sklearn.model_selection import train_test_split
from bltk.langtools import Tokenizer # BLTK: The Bengali Natural Language Processing Toolkit
from bltk.langtools import remove_stopwords
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix, accuracy_score
from sklearn.metrics import make_scorer, roc_auc_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV 
from scipy import stats
import matplotlib.pyplot as plt
import sklearn.metrics as metrics

import collections
import nltk
import numpy as np
import pandas as pd
import codecs

# %%
from bltk.langtools.banglachars import (vowels,
                                        vowel_signs,
                                        consonants,
                                        digits,
                                        operators,
                                        punctuations,
                                        others)

# %%
print(f'Vowels: {vowels}')
print(f'Vowel signs: {vowel_signs}')
print(f'Consonants: {consonants}')
print(f'Digits: {digits}')
print(f'Operators: {operators}')
print(f'Punctuation marks: {punctuations}')
print(f'Others: {others}')
# Out:
# Vowels: ['অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ', 'ঋ', 'ঌ', 'এ', 'ঐ', 'ও', 'ঔ']
# Vowel signs: ['া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ৄ', 'ে', 'ৈ', 'ো', 'ৌ']
# Consonants: ['ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', 'ড়', 'ঢ়', 'য়', 'ৎ', 'ং', 'ঃ', 'ঁ']
# Digits: ['০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯']
# Operators: ['=', '+', '-', '*', '/', '%', '<', '>', '×', '÷']
# Punctuation marks: ['।', ',', ';', ':', '?', '!', "'", '.', '"', '-', '[', ']', '{', '}', '(', ')', '–', '—', '―', '~']
# Others: ['৳', '৺', '্', 'ঀ', 'ঽ', '#', '$']

# %%
INPUT_FILE = "comment2.txt"
stopwords_list ="stopwords.txt"

# %% [markdown]
# ##**Dataset Preparation and Cleaning**

# %%
counter = collections.Counter()
tokenizer = Tokenizer()
maxlen = 0
xs, ys = [], []
bangla_stopwords = codecs.open(stopwords_list,'r',encoding='utf-8').read().split()
# print(bangla_stopwords)
# print(len(bangla_stopwords))


fin = codecs.open(INPUT_FILE, "r", encoding='utf-8')
for line in fin:
  
    _, sent = line.strip().split("\t") #Stripping the dataset based on tab. That is stripping label from sentence
    print("Label: ", _)
    print("Sentence: ",sent)

    words = tokenizer.word_tokenizer(sent)
    print("Afert Tokenizing: ",words)

    wordsExcludingPunctuationMarks=[word for word in words if word not in punctuations]
    print("Truncating punctuation:", wordsExcludingPunctuationMarks)
    
    wordsExcludingStopWords = [word.strip() for word in wordsExcludingPunctuationMarks if word not in bangla_stopwords]
    print("Truncating StopWords:", wordsExcludingStopWords)

#     if len(wordsExcludingStopWords) > maxlen: #For calculating the maximum number of words in a sentence
#         maxlen = len(wordsExcludingStopWords) 
#         print(maxlen)
#     for wordExcludingStopWords in wordsExcludingStopWords:
#         counter[wordExcludingStopWords] += 1 #Putting the frequency of each  word in a dictionary
#         print(counter[wordExcludingStopWords])
#     print("***************************************************************************************")

    ys.append(int(_))
    xs.append(' '.join(wordsExcludingStopWords))


fin.close()
# Out:
# Label:  1
# Sentence:  ভালো একটি প্রোডাক্ট পেয়েছি ধন্যবাদ দারাজ ধন্যবাদ ডেলিভারি বয় এন্ড ইউজ করে আরো ভালো লাগছে অন্যেরাও কিনতে পারেন আপনাদের পূর্ণ খুব ভালো
# Afert Tokenizing:  ['ভালো', 'একটি', 'প্রোডাক্ট', 'পেয়েছি', 'ধন্যবাদ', 'দারাজ', 'ধন্যবাদ', 'ডেলিভারি', 'বয়', 'এন্ড', 'ইউজ', 'করে', 'আরো', 'ভালো', 'লাগছে', 'অন্যেরাও', 'কিনতে', 'পারেন', 'আপনাদের', 'পূর্ণ', 'খুব', 'ভালো']
# Truncating punctuation: ['ভালো', 'একটি', 'প্রোডাক্ট', 'পেয়েছি', 'ধন্যবাদ', 'দারাজ', 'ধন্যবাদ', 'ডেলিভারি', 'বয়', 'এন্ড', 'ইউজ', 'করে', 'আরো', 'ভালো', 'লাগছে', 'অন্যেরাও', 'কিনতে', 'পারেন', 'আপনাদের', 'পূর্ণ', 'খুব', 'ভালো']
# Truncating StopWords: ['ভালো', 'প্রোডাক্ট', 'পেয়েছি', 'ধন্যবাদ', 'দারাজ', 'ধন্যবাদ', 'ডেলিভারি', 'বয়', 'এন্ড', 'ইউজ', 'আরো', 'ভালো', 'লাগছে', 'অন্যেরাও', 'কিনতে', 'আপনাদের', 'পূর্ণ', 'ভালো']
# 18
# 1
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 1
# 3
# ***************************************************************************************
# Label:  1
# Sentence:  এবং আপনাদের ডেলিভারি মেন খুব ভালো
# Afert Tokenizing:  ['এবং', 'আপনাদের', 'ডেলিভারি', 'মেন', 'খুব', 'ভালো']
# Truncating punctuation: ['এবং', 'আপনাদের', 'ডেলিভারি', 'মেন', 'খুব', 'ভালো']
# Truncating StopWords: ['আপনাদের', 'ডেলিভারি', 'মেন', 'ভালো']
# 2
# 2
# 1
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  অনেক তাড়াতাড়ি পণ্য পেয়ে গেলাম,ধন্যবাদ
# Afert Tokenizing:  ['অনেক', 'তাড়াতাড়ি', 'পণ্য', 'পেয়ে', 'গেলাম,ধন্যবাদ']
# Truncating punctuation: ['অনেক', 'তাড়াতাড়ি', 'পণ্য', 'পেয়ে', 'গেলাম,ধন্যবাদ']
# Truncating StopWords: ['তাড়াতাড়ি', 'পণ্য', 'গেলাম,ধন্যবাদ']
# 1
# 1
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  একদম ভাল না সবিতে যেরকম সিলো তেমন না পুরান
# Afert Tokenizing:  ['একদম', 'ভাল', 'না', 'সবিতে', 'যেরকম', 'সিলো', 'তেমন', 'না', 'পুরান']
# Truncating punctuation: ['একদম', 'ভাল', 'না', 'সবিতে', 'যেরকম', 'সিলো', 'তেমন', 'না', 'পুরান']
# Truncating StopWords: ['একদম', 'ভাল', 'না', 'সবিতে', 'যেরকম', 'সিলো', 'না', 'পুরান']
# 1
# 1
# 1
# 1
# 1
# 1
# 2
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  রিটান দিলে নেয়না
# Afert Tokenizing:  ['রিটান', 'দিলে', 'নেয়না']
# Truncating punctuation: ['রিটান', 'দিলে', 'নেয়না']
# Truncating StopWords: ['রিটান', 'দিলে', 'নেয়না']
# 1
# 1
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  সামনে হলে নিতাম না
# Afert Tokenizing:  ['সামনে', 'হলে', 'নিতাম', 'না']
# Truncating punctuation: ['সামনে', 'হলে', 'নিতাম', 'না']
# Truncating StopWords: ['নিতাম', 'না']
# 1
# 3
# ***************************************************************************************
# Label:  -1
# Sentence:  কেউ নিবেন না
# Afert Tokenizing:  ['কেউ', 'নিবেন', 'না']
# Truncating punctuation: ['কেউ', 'নিবেন', 'না']
# Truncating StopWords: ['নিবেন', 'না']
# 1
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  অল্প টাকায় প্রডাক্ট টা অনেক ভালো
# Afert Tokenizing:  ['অল্প', 'টাকায়', 'প্রডাক্ট', 'টা', 'অনেক', 'ভালো']
# Truncating punctuation: ['অল্প', 'টাকায়', 'প্রডাক্ট', 'টা', 'অনেক', 'ভালো']
# Truncating StopWords: ['অল্প', 'টাকায়', 'প্রডাক্ট', 'টা', 'ভালো']
# 1
# 1
# 1
# 1
# 5
# ***************************************************************************************
# Label:  1
# Sentence:  বিড়ি খোর দের খুব দরকারি একটা প্রডাক্ট চাইলে নিতে পারেন
# Afert Tokenizing:  ['বিড়ি', 'খোর', 'দের', 'খুব', 'দরকারি', 'একটা', 'প্রডাক্ট', 'চাইলে', 'নিতে', 'পারেন']
# Truncating punctuation: ['বিড়ি', 'খোর', 'দের', 'খুব', 'দরকারি', 'একটা', 'প্রডাক্ট', 'চাইলে', 'নিতে', 'পারেন']
# Truncating StopWords: ['বিড়ি', 'খোর', 'দের', 'দরকারি', 'একটা', 'প্রডাক্ট', 'চাইলে']
# 1
# 1
# 1
# 1
# 1
# 2
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  সেলারের ব্যবহার ও অনেক ভালো ছিলো
# Afert Tokenizing:  ['সেলারের', 'ব্যবহার', 'ও', 'অনেক', 'ভালো', 'ছিলো']
# Truncating punctuation: ['সেলারের', 'ব্যবহার', 'ও', 'অনেক', 'ভালো', 'ছিলো']
# Truncating StopWords: ['সেলারের', 'ভালো', 'ছিলো']
# 1
# 6
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  ধন্যবাদ দারাজ কে
# Afert Tokenizing:  ['ধন্যবাদ', 'দারাজ', 'কে']
# Truncating punctuation: ['ধন্যবাদ', 'দারাজ', 'কে']
# Truncating StopWords: ['ধন্যবাদ', 'দারাজ']
# 3
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  লাইটার টা অনেক সুন্দর
# Afert Tokenizing:  ['লাইটার', 'টা', 'অনেক', 'সুন্দর']
# Truncating punctuation: ['লাইটার', 'টা', 'অনেক', 'সুন্দর']
# Truncating StopWords: ['লাইটার', 'টা', 'সুন্দর']
# 1
# 2
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  ব্যাটারি ক্যাপাসিটি আরেকটু বেশি হলে ভালো হতো দাম অনুযায়ী ঠিক আছে
# Afert Tokenizing:  ['ব্যাটারি', 'ক্যাপাসিটি', 'আরেকটু', 'বেশি', 'হলে', 'ভালো', 'হতো', 'দাম', 'অনুযায়ী', 'ঠিক', 'আছে']
# Truncating punctuation: ['ব্যাটারি', 'ক্যাপাসিটি', 'আরেকটু', 'বেশি', 'হলে', 'ভালো', 'হতো', 'দাম', 'অনুযায়ী', 'ঠিক', 'আছে']
# Truncating StopWords: ['ব্যাটারি', 'ক্যাপাসিটি', 'আরেকটু', 'বেশি', 'ভালো', 'হতো', 'দাম', 'ঠিক']
# 1
# 1
# 1
# 1
# 7
# 1
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  তবে একটা কথা না বললেই নয় প্যাকেটটা একদম ইনটেক ভাবে করা ছিল এর দারাজ ও সেলারকে ধন্যবাদ
# Afert Tokenizing:  ['তবে', 'একটা', 'কথা', 'না', 'বললেই', 'নয়', 'প্যাকেটটা', 'একদম', 'ইনটেক', 'ভাবে', 'করা', 'ছিল', 'এর', 'দারাজ', 'ও', 'সেলারকে', 'ধন্যবাদ']
# Truncating punctuation: ['তবে', 'একটা', 'কথা', 'না', 'বললেই', 'নয়', 'প্যাকেটটা', 'একদম', 'ইনটেক', 'ভাবে', 'করা', 'ছিল', 'এর', 'দারাজ', 'ও', 'সেলারকে', 'ধন্যবাদ']
# Truncating StopWords: ['একটা', 'কথা', 'না', 'বললেই', 'নয়', 'প্যাকেটটা', 'একদম', 'ইনটেক', 'দারাজ', 'সেলারকে', 'ধন্যবাদ']
# 2
# 1
# 5
# 1
# 1
# 1
# 2
# 1
# 3
# 1
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  অল দ্যা বেস্ট দারাজ
# Afert Tokenizing:  ['অল', 'দ্যা', 'বেস্ট', 'দারাজ']
# Truncating punctuation: ['অল', 'দ্যা', 'বেস্ট', 'দারাজ']
# Truncating StopWords: ['অল', 'দ্যা', 'বেস্ট', 'দারাজ']
# 1
# 1
# 1
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  অল্প টাকায় প্রডাক্ট টা অনেক ভালো
# Afert Tokenizing:  ['অল্প', 'টাকায়', 'প্রডাক্ট', 'টা', 'অনেক', 'ভালো']
# Truncating punctuation: ['অল্প', 'টাকায়', 'প্রডাক্ট', 'টা', 'অনেক', 'ভালো']
# Truncating StopWords: ['অল্প', 'টাকায়', 'প্রডাক্ট', 'টা', 'ভালো']
# 2
# 2
# 3
# 3
# 8
# ***************************************************************************************
# Label:  1
# Sentence:  সেলারের ব্যবহার ও অনেক ভালো ছিলো
# Afert Tokenizing:  ['সেলারের', 'ব্যবহার', 'ও', 'অনেক', 'ভালো', 'ছিলো']
# Truncating punctuation: ['সেলারের', 'ব্যবহার', 'ও', 'অনেক', 'ভালো', 'ছিলো']
# Truncating StopWords: ['সেলারের', 'ভালো', 'ছিলো']
# 2
# 9
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  অনেক ভালো প্রডাক্ট টি চাইলে আপনারা কিনতে পারেন
# Afert Tokenizing:  ['অনেক', 'ভালো', 'প্রডাক্ট', 'টি', 'চাইলে', 'আপনারা', 'কিনতে', 'পারেন']
# Truncating punctuation: ['অনেক', 'ভালো', 'প্রডাক্ট', 'টি', 'চাইলে', 'আপনারা', 'কিনতে', 'পারেন']
# Truncating StopWords: ['ভালো', 'প্রডাক্ট', 'চাইলে', 'আপনারা', 'কিনতে']
# 10
# 4
# 2
# 1
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  আলহামদুলিল্লাহ প্রোডাক্ট টা খুবই ভালো
# Afert Tokenizing:  ['আলহামদুলিল্লাহ', 'প্রোডাক্ট', 'টা', 'খুবই', 'ভালো']
# Truncating punctuation: ['আলহামদুলিল্লাহ', 'প্রোডাক্ট', 'টা', 'খুবই', 'ভালো']
# Truncating StopWords: ['আলহামদুলিল্লাহ', 'প্রোডাক্ট', 'টা', 'খুবই', 'ভালো']
# 1
# 2
# 4
# 1
# 11
# ***************************************************************************************
# Label:  1
# Sentence:  আলহামদুলিল্লাহ ভালো প্রোডাক্টটা ভালো চার্জ ভালো থাকে ভালো কাজ করে আপনারা নিতে চাইলে নিতে পারেন
# Afert Tokenizing:  ['আলহামদুলিল্লাহ', 'ভালো', 'প্রোডাক্টটা', 'ভালো', 'চার্জ', 'ভালো', 'থাকে', 'ভালো', 'কাজ', 'করে', 'আপনারা', 'নিতে', 'চাইলে', 'নিতে', 'পারেন']
# Truncating punctuation: ['আলহামদুলিল্লাহ', 'ভালো', 'প্রোডাক্টটা', 'ভালো', 'চার্জ', 'ভালো', 'থাকে', 'ভালো', 'কাজ', 'করে', 'আপনারা', 'নিতে', 'চাইলে', 'নিতে', 'পারেন']
# Truncating StopWords: ['আলহামদুলিল্লাহ', 'ভালো', 'প্রোডাক্টটা', 'ভালো', 'চার্জ', 'ভালো', 'ভালো', 'আপনারা', 'চাইলে']
# 2
# 12
# 1
# 13
# 1
# 14
# 15
# 2
# 3
# ***************************************************************************************
# Label:  1
# Sentence:  সেলার ভাইকে অনেক ধন্যবাদ কারন আমাকে আমার পন্য আমার বাসাত ঠিক ভাবে দেয়ার জন্য
# Afert Tokenizing:  ['সেলার', 'ভাইকে', 'অনেক', 'ধন্যবাদ', 'কারন', 'আমাকে', 'আমার', 'পন্য', 'আমার', 'বাসাত', 'ঠিক', 'ভাবে', 'দেয়ার', 'জন্য']
# Truncating punctuation: ['সেলার', 'ভাইকে', 'অনেক', 'ধন্যবাদ', 'কারন', 'আমাকে', 'আমার', 'পন্য', 'আমার', 'বাসাত', 'ঠিক', 'ভাবে', 'দেয়ার', 'জন্য']
# Truncating StopWords: ['সেলার', 'ভাইকে', 'ধন্যবাদ', 'কারন', 'পন্য', 'বাসাত', 'ঠিক', 'দেয়ার']
# 1
# 1
# 5
# 1
# 1
# 1
# 2
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  ভালো আছে আপনারা নিতে পারেন
# Afert Tokenizing:  ['ভালো', 'আছে', 'আপনারা', 'নিতে', 'পারেন']
# Truncating punctuation: ['ভালো', 'আছে', 'আপনারা', 'নিতে', 'পারেন']
# Truncating StopWords: ['ভালো', 'আপনারা']
# 16
# 3
# ***************************************************************************************
# Label:  1
# Sentence:  জিনিস টা খুপ ভালো আপনারা নিতে চাইলে নিতে পারেন
# Afert Tokenizing:  ['জিনিস', 'টা', 'খুপ', 'ভালো', 'আপনারা', 'নিতে', 'চাইলে', 'নিতে', 'পারেন']
# Truncating punctuation: ['জিনিস', 'টা', 'খুপ', 'ভালো', 'আপনারা', 'নিতে', 'চাইলে', 'নিতে', 'পারেন']
# Truncating StopWords: ['জিনিস', 'টা', 'খুপ', 'ভালো', 'আপনারা', 'চাইলে']
# 1
# 5
# 1
# 17
# 4
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল আছে সবাই নিতে পারেন
# Afert Tokenizing:  ['ভাল', 'আছে', 'সবাই', 'নিতে', 'পারেন']
# Truncating punctuation: ['ভাল', 'আছে', 'সবাই', 'নিতে', 'পারেন']
# Truncating StopWords: ['ভাল', 'সবাই']
# 2
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  যেমন টা দেখে অর্ডার করছিলাম ঠিক তেমনটাই পেয়েছি ধন্যবাদ দার আজকে ধন্যবাদ ছেলের কে
# Afert Tokenizing:  ['যেমন', 'টা', 'দেখে', 'অর্ডার', 'করছিলাম', 'ঠিক', 'তেমনটাই', 'পেয়েছি', 'ধন্যবাদ', 'দার', 'আজকে', 'ধন্যবাদ', 'ছেলের', 'কে']
# Truncating punctuation: ['যেমন', 'টা', 'দেখে', 'অর্ডার', 'করছিলাম', 'ঠিক', 'তেমনটাই', 'পেয়েছি', 'ধন্যবাদ', 'দার', 'আজকে', 'ধন্যবাদ', 'ছেলের', 'কে']
# Truncating StopWords: ['টা', 'অর্ডার', 'করছিলাম', 'ঠিক', 'তেমনটাই', 'পেয়েছি', 'ধন্যবাদ', 'দার', 'আজকে', 'ধন্যবাদ', 'ছেলের']
# 6
# 1
# 1
# 3
# 1
# 2
# 6
# 1
# 1
# 7
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  এত কম দামে জিনিস টা অনেক ভালো
# Afert Tokenizing:  ['এত', 'কম', 'দামে', 'জিনিস', 'টা', 'অনেক', 'ভালো']
# Truncating punctuation: ['এত', 'কম', 'দামে', 'জিনিস', 'টা', 'অনেক', 'ভালো']
# Truncating StopWords: ['কম', 'দামে', 'জিনিস', 'টা', 'ভালো']
# 1
# 1
# 2
# 7
# 18
# ***************************************************************************************
# Label:  1
# Sentence:  আপনেও চাইলে কিনতে পারেন কোনো সমস্যা নাই
# Afert Tokenizing:  ['আপনেও', 'চাইলে', 'কিনতে', 'পারেন', 'কোনো', 'সমস্যা', 'নাই']
# Truncating punctuation: ['আপনেও', 'চাইলে', 'কিনতে', 'পারেন', 'কোনো', 'সমস্যা', 'নাই']
# Truncating StopWords: ['আপনেও', 'চাইলে', 'কিনতে', 'সমস্যা', 'নাই']
# 1
# 5
# 3
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  দেখতে খুব ভালো লাগসে
# Afert Tokenizing:  ['দেখতে', 'খুব', 'ভালো', 'লাগসে']
# Truncating punctuation: ['দেখতে', 'খুব', 'ভালো', 'লাগসে']
# Truncating StopWords: ['ভালো', 'লাগসে']
# 19
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  সুন্দর একটা লাইটার
# Afert Tokenizing:  ['সুন্দর', 'একটা', 'লাইটার']
# Truncating punctuation: ['সুন্দর', 'একটা', 'লাইটার']
# Truncating StopWords: ['সুন্দর', 'একটা', 'লাইটার']
# 2
# 3
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  ১৬৫ টাকা হিসেবে ভাল পরেছে
# Afert Tokenizing:  ['১৬৫', 'টাকা', 'হিসেবে', 'ভাল', 'পরেছে']
# Truncating punctuation: ['১৬৫', 'টাকা', 'হিসেবে', 'ভাল', 'পরেছে']
# Truncating StopWords: ['১৬৫', 'টাকা', 'হিসেবে', 'ভাল', 'পরেছে']
# 1
# 1
# 1
# 3
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  দুর্দান্ত পণ্য
# Afert Tokenizing:  ['দুর্দান্ত', 'পণ্য']
# Truncating punctuation: ['দুর্দান্ত', 'পণ্য']
# Truncating StopWords: ['দুর্দান্ত', 'পণ্য']
# 1
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  আপনি যদি একটি পোর্টেবল লাইটার চান তবে আপনি এটি কিনতে পারেন
# Afert Tokenizing:  ['আপনি', 'যদি', 'একটি', 'পোর্টেবল', 'লাইটার', 'চান', 'তবে', 'আপনি', 'এটি', 'কিনতে', 'পারেন']
# Truncating punctuation: ['আপনি', 'যদি', 'একটি', 'পোর্টেবল', 'লাইটার', 'চান', 'তবে', 'আপনি', 'এটি', 'কিনতে', 'পারেন']
# Truncating StopWords: ['পোর্টেবল', 'লাইটার', 'কিনতে']
# 1
# 3
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  ছবির মত একই
# Afert Tokenizing:  ['ছবির', 'মত', 'একই']
# Truncating punctuation: ['ছবির', 'মত', 'একই']
# Truncating StopWords: ['ছবির', 'মত']
# 1
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  এটি  একটি মাঝামাঝি ধরন পণ্য
# Afert Tokenizing:  ['এটি', 'একটি', 'মাঝামাঝি', 'ধরন', 'পণ্য']
# Truncating punctuation: ['এটি', 'একটি', 'মাঝামাঝি', 'ধরন', 'পণ্য']
# Truncating StopWords: ['মাঝামাঝি', 'ধরন', 'পণ্য']
# 1
# 1
# 3
# ***************************************************************************************
# Label:  0
# Sentence:  শুধুমাত্র মজার জন্য এটি অর্ডার করুন
# Afert Tokenizing:  ['শুধুমাত্র', 'মজার', 'জন্য', 'এটি', 'অর্ডার', 'করুন']
# Truncating punctuation: ['শুধুমাত্র', 'মজার', 'জন্য', 'এটি', 'অর্ডার', 'করুন']
# Truncating StopWords: ['শুধুমাত্র', 'মজার', 'অর্ডার', 'করুন']
# 1
# 1
# 2
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  খুব ভালো একটা প্রোর্ডাকট প্রথমে ভাবেছিলা ভালো হবে না কিছু দিন ব্যবহার করে দেখলাম যা চেয়েছি তার থেকে ভালো পেয়েছি আপনারা চাইলে নিতে পারেন ধন্যবাদ দারাজ এবং ডেলিভারি মেন কে
# Afert Tokenizing:  ['খুব', 'ভালো', 'একটা', 'প্রোর্ডাকট', 'প্রথমে', 'ভাবেছিলা', 'ভালো', 'হবে', 'না', 'কিছু', 'দিন', 'ব্যবহার', 'করে', 'দেখলাম', 'যা', 'চেয়েছি', 'তার', 'থেকে', 'ভালো', 'পেয়েছি', 'আপনারা', 'চাইলে', 'নিতে', 'পারেন', 'ধন্যবাদ', 'দারাজ', 'এবং', 'ডেলিভারি', 'মেন', 'কে']
# Truncating punctuation: ['খুব', 'ভালো', 'একটা', 'প্রোর্ডাকট', 'প্রথমে', 'ভাবেছিলা', 'ভালো', 'হবে', 'না', 'কিছু', 'দিন', 'ব্যবহার', 'করে', 'দেখলাম', 'যা', 'চেয়েছি', 'তার', 'থেকে', 'ভালো', 'পেয়েছি', 'আপনারা', 'চাইলে', 'নিতে', 'পারেন', 'ধন্যবাদ', 'দারাজ', 'এবং', 'ডেলিভারি', 'মেন', 'কে']
# Truncating StopWords: ['ভালো', 'একটা', 'প্রোর্ডাকট', 'প্রথমে', 'ভাবেছিলা', 'ভালো', 'না', 'দেখলাম', 'চেয়েছি', 'ভালো', 'পেয়েছি', 'আপনারা', 'চাইলে', 'ধন্যবাদ', 'দারাজ', 'ডেলিভারি', 'মেন']
# 20
# 4
# 1
# 1
# 1
# 21
# 6
# 1
# 1
# 22
# 1
# 5
# 6
# 8
# 5
# 3
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  যেরকম চেয়েছিলাম আলহামদুলিল্লাহ অনেক ভালো পেয়েছি দারাজ একটি দারুন শপিং মার্কেট আপনারা চাইলে কিনতে পারেন
# Afert Tokenizing:  ['যেরকম', 'চেয়েছিলাম', 'আলহামদুলিল্লাহ', 'অনেক', 'ভালো', 'পেয়েছি', 'দারাজ', 'একটি', 'দারুন', 'শপিং', 'মার্কেট', 'আপনারা', 'চাইলে', 'কিনতে', 'পারেন']
# Truncating punctuation: ['যেরকম', 'চেয়েছিলাম', 'আলহামদুলিল্লাহ', 'অনেক', 'ভালো', 'পেয়েছি', 'দারাজ', 'একটি', 'দারুন', 'শপিং', 'মার্কেট', 'আপনারা', 'চাইলে', 'কিনতে', 'পারেন']
# Truncating StopWords: ['যেরকম', 'চেয়েছিলাম', 'আলহামদুলিল্লাহ', 'ভালো', 'পেয়েছি', 'দারাজ', 'দারুন', 'শপিং', 'মার্কেট', 'আপনারা', 'চাইলে', 'কিনতে']
# 2
# 1
# 3
# 23
# 3
# 6
# 1
# 1
# 1
# 6
# 7
# 5
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল পণ্য
# Afert Tokenizing:  ['ভাল', 'পণ্য']
# Truncating punctuation: ['ভাল', 'পণ্য']
# Truncating StopWords: ['ভাল', 'পণ্য']
# 4
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  ভালো বিক্রেতা
# Afert Tokenizing:  ['ভালো', 'বিক্রেতা']
# Truncating punctuation: ['ভালো', 'বিক্রেতা']
# Truncating StopWords: ['ভালো', 'বিক্রেতা']
# 24
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  এটা খুব ভাল প্রাণঘাতী
# Afert Tokenizing:  ['এটা', 'খুব', 'ভাল', 'প্রাণঘাতী']
# Truncating punctuation: ['এটা', 'খুব', 'ভাল', 'প্রাণঘাতী']
# Truncating StopWords: ['ভাল', 'প্রাণঘাতী']
# 5
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  আমি সন্তুষ্ট
# Afert Tokenizing:  ['আমি', 'সন্তুষ্ট']
# Truncating punctuation: ['আমি', 'সন্তুষ্ট']
# Truncating StopWords: ['সন্তুষ্ট']
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  পণ্য ১০/১০
# Afert Tokenizing:  ['পণ্য', '১০/১০']
# Truncating punctuation: ['পণ্য', '১০/১০']
# Truncating StopWords: ['পণ্য', '১০/১০']
# 5
# 1
# ***************************************************************************************
# Label:  0
# Sentence:  চার্জ দুই দিনের জন্য থাকবে
# Afert Tokenizing:  ['চার্জ', 'দুই', 'দিনের', 'জন্য', 'থাকবে']
# Truncating punctuation: ['চার্জ', 'দুই', 'দিনের', 'জন্য', 'থাকবে']
# Truncating StopWords: ['চার্জ', 'দিনের']
# 2
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  একদম লাইট ওয়েট
# Afert Tokenizing:  ['একদম', 'লাইট', 'ওয়েট']
# Truncating punctuation: ['একদম', 'লাইট', 'ওয়েট']
# Truncating StopWords: ['একদম', 'লাইট', 'ওয়েট']
# 3
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  আর পাশে ও অনেক পাতলা
# Afert Tokenizing:  ['আর', 'পাশে', 'ও', 'অনেক', 'পাতলা']
# Truncating punctuation: ['আর', 'পাশে', 'ও', 'অনেক', 'পাতলা']
# Truncating StopWords: ['পাশে', 'পাতলা']
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  ভালো কিছু আশা করলে দারাজ এর সাথে থাকুন
# Afert Tokenizing:  ['ভালো', 'কিছু', 'আশা', 'করলে', 'দারাজ', 'এর', 'সাথে', 'থাকুন']
# Truncating punctuation: ['ভালো', 'কিছু', 'আশা', 'করলে', 'দারাজ', 'এর', 'সাথে', 'থাকুন']
# Truncating StopWords: ['ভালো', 'আশা', 'দারাজ', 'সাথে', 'থাকুন']
# 25
# 1
# 7
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  জিনিস টা অনেক ভালো
# Afert Tokenizing:  ['জিনিস', 'টা', 'অনেক', 'ভালো']
# Truncating punctuation: ['জিনিস', 'টা', 'অনেক', 'ভালো']
# Truncating StopWords: ['জিনিস', 'টা', 'ভালো']
# 3
# 8
# 26
# ***************************************************************************************
# Label:  1
# Sentence:  আপনারাও নিতে পারেন
# Afert Tokenizing:  ['আপনারাও', 'নিতে', 'পারেন']
# Truncating punctuation: ['আপনারাও', 'নিতে', 'পারেন']
# Truncating StopWords: ['আপনারাও']
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  যদিও এটি প্লাস্টিকের তৈরি, কিন্তু সূক্ষ্ম কাজ করে
# Afert Tokenizing:  ['যদিও', 'এটি', 'প্লাস্টিকের', 'তৈরি', ',', 'কিন্তু', 'সূক্ষ্ম', 'কাজ', 'করে']
# Truncating punctuation: ['যদিও', 'এটি', 'প্লাস্টিকের', 'তৈরি', 'কিন্তু', 'সূক্ষ্ম', 'কাজ', 'করে']
# Truncating StopWords: ['প্লাস্টিকের', 'তৈরি', 'সূক্ষ্ম']
# 1
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  এটা খুবই ভালো একটা প্রডাক্ট
# Afert Tokenizing:  ['এটা', 'খুবই', 'ভালো', 'একটা', 'প্রডাক্ট']
# Truncating punctuation: ['এটা', 'খুবই', 'ভালো', 'একটা', 'প্রডাক্ট']
# Truncating StopWords: ['খুবই', 'ভালো', 'একটা', 'প্রডাক্ট']
# 2
# 27
# 5
# 5
# ***************************************************************************************
# Label:  1
# Sentence:  ব্যাবহার করা একদম সহজ বাতাসেও নিভে যাওয়ার কোনো ভয় নেই
# Afert Tokenizing:  ['ব্যাবহার', 'করা', 'একদম', 'সহজ', 'বাতাসেও', 'নিভে', 'যাওয়ার', 'কোনো', 'ভয়', 'নেই']
# Truncating punctuation: ['ব্যাবহার', 'করা', 'একদম', 'সহজ', 'বাতাসেও', 'নিভে', 'যাওয়ার', 'কোনো', 'ভয়', 'নেই']
# Truncating StopWords: ['ব্যাবহার', 'একদম', 'সহজ', 'বাতাসেও', 'নিভে', 'যাওয়ার', 'ভয়', 'নেই']
# 1
# 4
# 1
# 1
# 1
# 1
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  ধন্যবাদ জানায় 'দারাজ'কে এবং এনাদের সঙ্গে যুক্ত সকলকে ধন্যবাদ
# Afert Tokenizing:  ['ধন্যবাদ', 'জানায়', "দারাজ'কে", "'", 'এবং', 'এনাদের', 'সঙ্গে', 'যুক্ত', 'সকলকে', 'ধন্যবাদ']
# Truncating punctuation: ['ধন্যবাদ', 'জানায়', "দারাজ'কে", 'এবং', 'এনাদের', 'সঙ্গে', 'যুক্ত', 'সকলকে', 'ধন্যবাদ']
# Truncating StopWords: ['ধন্যবাদ', 'জানায়', "দারাজ'কে", 'এনাদের', 'যুক্ত', 'সকলকে', 'ধন্যবাদ']
# 9
# 1
# 1
# 1
# 1
# 1
# 10
# ***************************************************************************************
# Label:  1
# Sentence:  দাম হিসেবে খুব ভালো একটা লাইটার আপনারা চাইলে নিতে পারেন
# Afert Tokenizing:  ['দাম', 'হিসেবে', 'খুব', 'ভালো', 'একটা', 'লাইটার', 'আপনারা', 'চাইলে', 'নিতে', 'পারেন']
# Truncating punctuation: ['দাম', 'হিসেবে', 'খুব', 'ভালো', 'একটা', 'লাইটার', 'আপনারা', 'চাইলে', 'নিতে', 'পারেন']
# Truncating StopWords: ['দাম', 'হিসেবে', 'ভালো', 'একটা', 'লাইটার', 'আপনারা', 'চাইলে']
# 2
# 2
# 28
# 6
# 4
# 7
# 8
# ***************************************************************************************
# Label:  1
# Sentence:  অনেক বেশি ভালো একটা প্রডাক্ট
# Afert Tokenizing:  ['অনেক', 'বেশি', 'ভালো', 'একটা', 'প্রডাক্ট']
# Truncating punctuation: ['অনেক', 'বেশি', 'ভালো', 'একটা', 'প্রডাক্ট']
# Truncating StopWords: ['বেশি', 'ভালো', 'একটা', 'প্রডাক্ট']
# 2
# 29
# 7
# 6
# ***************************************************************************************
# Label:  1
# Sentence:  চাইলে নিতে পারেন সবাই
# Afert Tokenizing:  ['চাইলে', 'নিতে', 'পারেন', 'সবাই']
# Truncating punctuation: ['চাইলে', 'নিতে', 'পারেন', 'সবাই']
# Truncating StopWords: ['চাইলে', 'সবাই']
# 9
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  আমার খুব ভালো লাগছে
# Afert Tokenizing:  ['আমার', 'খুব', 'ভালো', 'লাগছে']
# Truncating punctuation: ['আমার', 'খুব', 'ভালো', 'লাগছে']
# Truncating StopWords: ['ভালো', 'লাগছে']
# 30
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  ধন্যবাদ
# Afert Tokenizing:  ['ধন্যবাদ']
# Truncating punctuation: ['ধন্যবাদ']
# Truncating StopWords: ['ধন্যবাদ']
# 11
# ***************************************************************************************
# Label:  1
# Sentence:  এটা আমার চিন্তার চেয়েও ভালো
# Afert Tokenizing:  ['এটা', 'আমার', 'চিন্তার', 'চেয়েও', 'ভালো']
# Truncating punctuation: ['এটা', 'আমার', 'চিন্তার', 'চেয়েও', 'ভালো']
# Truncating StopWords: ['চিন্তার', 'চেয়েও', 'ভালো']
# 1
# 1
# 31
# ***************************************************************************************
# Label:  1
# Sentence:  এমন একটি ভাল পণ্য দেওয়ার জন্য বিক্রেতাকে ধন্যবাদ
# Afert Tokenizing:  ['এমন', 'একটি', 'ভাল', 'পণ্য', 'দেওয়ার', 'জন্য', 'বিক্রেতাকে', 'ধন্যবাদ']
# Truncating punctuation: ['এমন', 'একটি', 'ভাল', 'পণ্য', 'দেওয়ার', 'জন্য', 'বিক্রেতাকে', 'ধন্যবাদ']
# Truncating StopWords: ['ভাল', 'পণ্য', 'বিক্রেতাকে', 'ধন্যবাদ']
# 6
# 6
# 1
# 12
# ***************************************************************************************
# Label:  1
# Sentence:  ধন্যবাদ সেলার কে প্রডাক্ট টা আসলে ভালো সবাই নিতে পারেন
# Afert Tokenizing:  ['ধন্যবাদ', 'সেলার', 'কে', 'প্রডাক্ট', 'টা', 'আসলে', 'ভালো', 'সবাই', 'নিতে', 'পারেন']
# Truncating punctuation: ['ধন্যবাদ', 'সেলার', 'কে', 'প্রডাক্ট', 'টা', 'আসলে', 'ভালো', 'সবাই', 'নিতে', 'পারেন']
# Truncating StopWords: ['ধন্যবাদ', 'সেলার', 'প্রডাক্ট', 'টা', 'আসলে', 'ভালো', 'সবাই']
# 13
# 2
# 7
# 9
# 1
# 32
# 3
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল পণ্য
# Afert Tokenizing:  ['ভাল', 'পণ্য']
# Truncating punctuation: ['ভাল', 'পণ্য']
# Truncating StopWords: ['ভাল', 'পণ্য']
# 7
# 7
# ***************************************************************************************
# Label:  -1
# Sentence:  লাইটার পেয়েছি কিন্তু চার্জার নেই
# Afert Tokenizing:  ['লাইটার', 'পেয়েছি', 'কিন্তু', 'চার্জার', 'নেই']
# Truncating punctuation: ['লাইটার', 'পেয়েছি', 'কিন্তু', 'চার্জার', 'নেই']
# Truncating StopWords: ['লাইটার', 'পেয়েছি', 'চার্জার', 'নেই']
# 5
# 4
# 1
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  দারাজ থেকে অনেক ভালো একটা পণ্য পেলাম
# Afert Tokenizing:  ['দারাজ', 'থেকে', 'অনেক', 'ভালো', 'একটা', 'পণ্য', 'পেলাম']
# Truncating punctuation: ['দারাজ', 'থেকে', 'অনেক', 'ভালো', 'একটা', 'পণ্য', 'পেলাম']
# Truncating StopWords: ['দারাজ', 'ভালো', 'একটা', 'পণ্য', 'পেলাম']
# 8
# 33
# 8
# 8
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  চার্জ থাকে না তাই রিটার্ন করলাম
# Afert Tokenizing:  ['চার্জ', 'থাকে', 'না', 'তাই', 'রিটার্ন', 'করলাম']
# Truncating punctuation: ['চার্জ', 'থাকে', 'না', 'তাই', 'রিটার্ন', 'করলাম']
# Truncating StopWords: ['চার্জ', 'না', 'রিটার্ন', 'করলাম']
# 3
# 7
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  দাম বিবেচনায় জিনিসটা ভালো
# Afert Tokenizing:  ['দাম', 'বিবেচনায়', 'জিনিসটা', 'ভালো']
# Truncating punctuation: ['দাম', 'বিবেচনায়', 'জিনিসটা', 'ভালো']
# Truncating StopWords: ['দাম', 'বিবেচনায়', 'জিনিসটা', 'ভালো']
# 3
# 1
# 1
# 34
# ***************************************************************************************
# Label:  1
# Sentence:  অনেক সুন্দর প্রোডাক্টটি
# Afert Tokenizing:  ['অনেক', 'সুন্দর', 'প্রোডাক্টটি']
# Truncating punctuation: ['অনেক', 'সুন্দর', 'প্রোডাক্টটি']
# Truncating StopWords: ['সুন্দর', 'প্রোডাক্টটি']
# 3
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  দারুন একটি প্রডাক্ট।
# Afert Tokenizing:  ['দারুন', 'একটি', 'প্রডাক্ট', '।']
# Truncating punctuation: ['দারুন', 'একটি', 'প্রডাক্ট']
# Truncating StopWords: ['দারুন', 'প্রডাক্ট']
# 2
# 8
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল পণ্য
# Afert Tokenizing:  ['ভাল', 'পণ্য']
# Truncating punctuation: ['ভাল', 'পণ্য']
# Truncating StopWords: ['ভাল', 'পণ্য']
# 8
# 9
# ***************************************************************************************
# Label:  1
# Sentence:  খুব সুন্দর প্রোডাক্ট। আমার খুব পচ্ছন্দ হয়েছে। দারাজকে ধন্যবাদ। এত সুন্দর প্রোডাক্ট দেবার জন্য।
# Afert Tokenizing:  ['খুব', 'সুন্দর', 'প্রোডাক্ট', '।', 'আমার', 'খুব', 'পচ্ছন্দ', 'হয়েছে', '।', 'দারাজকে', 'ধন্যবাদ', '।', 'এত', 'সুন্দর', 'প্রোডাক্ট', 'দেবার', 'জন্য', '।']
# Truncating punctuation: ['খুব', 'সুন্দর', 'প্রোডাক্ট', 'আমার', 'খুব', 'পচ্ছন্দ', 'হয়েছে', 'দারাজকে', 'ধন্যবাদ', 'এত', 'সুন্দর', 'প্রোডাক্ট', 'দেবার', 'জন্য']
# Truncating StopWords: ['সুন্দর', 'প্রোডাক্ট', 'পচ্ছন্দ', 'হয়েছে', 'দারাজকে', 'ধন্যবাদ', 'সুন্দর', 'প্রোডাক্ট', 'দেবার']
# 4
# 3
# 1
# 1
# 1
# 14
# 5
# 4
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  প্রডাক্ট ভাল কাজ করে ভাল বন্দুরা নিতে পারেন
# Afert Tokenizing:  ['প্রডাক্ট', 'ভাল', 'কাজ', 'করে', 'ভাল', 'বন্দুরা', 'নিতে', 'পারেন']
# Truncating punctuation: ['প্রডাক্ট', 'ভাল', 'কাজ', 'করে', 'ভাল', 'বন্দুরা', 'নিতে', 'পারেন']
# Truncating StopWords: ['প্রডাক্ট', 'ভাল', 'ভাল', 'বন্দুরা']
# 9
# 9
# 10
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  বেসি ভাল না ছবির মত এত ভাল না বাস্তবে
# Afert Tokenizing:  ['বেসি', 'ভাল', 'না', 'ছবির', 'মত', 'এত', 'ভাল', 'না', 'বাস্তবে']
# Truncating punctuation: ['বেসি', 'ভাল', 'না', 'ছবির', 'মত', 'এত', 'ভাল', 'না', 'বাস্তবে']
# Truncating StopWords: ['বেসি', 'ভাল', 'না', 'ছবির', 'মত', 'ভাল', 'না', 'বাস্তবে']
# 1
# 11
# 8
# 2
# 2
# 12
# 9
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  আমি পণ্য পাইনি
# Afert Tokenizing:  ['আমি', 'পণ্য', 'পাইনি']
# Truncating punctuation: ['আমি', 'পণ্য', 'পাইনি']
# Truncating StopWords: ['পণ্য', 'পাইনি']
# 10
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  লাইটার জ্বালিয়ে রাখলে গরম হয়ে যায় খুবই অল্প সময়ের ভিতরে অতিরিক্ত হিট হয়ে যায়
# Afert Tokenizing:  ['লাইটার', 'জ্বালিয়ে', 'রাখলে', 'গরম', 'হয়ে', 'যায়', 'খুবই', 'অল্প', 'সময়ের', 'ভিতরে', 'অতিরিক্ত', 'হিট', 'হয়ে', 'যায়']
# Truncating punctuation: ['লাইটার', 'জ্বালিয়ে', 'রাখলে', 'গরম', 'হয়ে', 'যায়', 'খুবই', 'অল্প', 'সময়ের', 'ভিতরে', 'অতিরিক্ত', 'হিট', 'হয়ে', 'যায়']
# Truncating StopWords: ['লাইটার', 'জ্বালিয়ে', 'রাখলে', 'গরম', 'খুবই', 'অল্প', 'সময়ের', 'ভিতরে', 'অতিরিক্ত', 'হিট']
# 6
# 1
# 1
# 1
# 3
# 3
# 1
# 1
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  প্রোডাক্ট এর মানে অনেক ভালো নিঃসন্দেহে কিনতে পারেন এটা আমার দ্বিতীয় অর্ডার ছিল
# Afert Tokenizing:  ['প্রোডাক্ট', 'এর', 'মানে', 'অনেক', 'ভালো', 'নিঃসন্দেহে', 'কিনতে', 'পারেন', 'এটা', 'আমার', 'দ্বিতীয়', 'অর্ডার', 'ছিল']
# Truncating punctuation: ['প্রোডাক্ট', 'এর', 'মানে', 'অনেক', 'ভালো', 'নিঃসন্দেহে', 'কিনতে', 'পারেন', 'এটা', 'আমার', 'দ্বিতীয়', 'অর্ডার', 'ছিল']
# Truncating StopWords: ['প্রোডাক্ট', 'মানে', 'ভালো', 'নিঃসন্দেহে', 'কিনতে', 'দ্বিতীয়', 'অর্ডার']
# 5
# 1
# 35
# 1
# 6
# 1
# 3
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল
# Afert Tokenizing:  ['ভাল']
# Truncating punctuation: ['ভাল']
# Truncating StopWords: ['ভাল']
# 13
# ***************************************************************************************
# Label:  1
# Sentence:  পণ্যটি খুব ভাল পেয়েছি
# Afert Tokenizing:  ['পণ্যটি', 'খুব', 'ভাল', 'পেয়েছি']
# Truncating punctuation: ['পণ্যটি', 'খুব', 'ভাল', 'পেয়েছি']
# Truncating StopWords: ['পণ্যটি', 'ভাল', 'পেয়েছি']
# 1
# 14
# 5
# ***************************************************************************************
# Label:  1
# Sentence:  বিক্রেতা খুব ভাল
# Afert Tokenizing:  ['বিক্রেতা', 'খুব', 'ভাল']
# Truncating punctuation: ['বিক্রেতা', 'খুব', 'ভাল']
# Truncating StopWords: ['বিক্রেতা', 'ভাল']
# 2
# 15
# ***************************************************************************************
# Label:  1
# Sentence:  ধন্যবাদ দারাজ
# Afert Tokenizing:  ['ধন্যবাদ', 'দারাজ']
# Truncating punctuation: ['ধন্যবাদ', 'দারাজ']
# Truncating StopWords: ['ধন্যবাদ', 'দারাজ']
# 15
# 9
# ***************************************************************************************
# Label:  1
# Sentence:  প্রোডাক্ট এর মান ভালো এটা আমার তৃতীয় অর্ডার ছিল নিতে পারেন সবাই
# Afert Tokenizing:  ['প্রোডাক্ট', 'এর', 'মান', 'ভালো', 'এটা', 'আমার', 'তৃতীয়', 'অর্ডার', 'ছিল', 'নিতে', 'পারেন', 'সবাই']
# Truncating punctuation: ['প্রোডাক্ট', 'এর', 'মান', 'ভালো', 'এটা', 'আমার', 'তৃতীয়', 'অর্ডার', 'ছিল', 'নিতে', 'পারেন', 'সবাই']
# Truncating StopWords: ['প্রোডাক্ট', 'মান', 'ভালো', 'তৃতীয়', 'অর্ডার', 'সবাই']
# 6
# 1
# 36
# 1
# 4
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  এই দামে চমৎকার পণ্য
# Afert Tokenizing:  ['এই', 'দামে', 'চমৎকার', 'পণ্য']
# Truncating punctuation: ['এই', 'দামে', 'চমৎকার', 'পণ্য']
# Truncating StopWords: ['দামে', 'চমৎকার', 'পণ্য']
# 2
# 1
# 11
# ***************************************************************************************
# Label:  1
# Sentence:  আমার সত্যিই এই সিস্টেম পছন্দ
# Afert Tokenizing:  ['আমার', 'সত্যিই', 'এই', 'সিস্টেম', 'পছন্দ']
# Truncating punctuation: ['আমার', 'সত্যিই', 'এই', 'সিস্টেম', 'পছন্দ']
# Truncating StopWords: ['সত্যিই', 'সিস্টেম', 'পছন্দ']
# 1
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  এটি সাধারণ নয় তাই এটি প্রদর্শনের জন্য ভাল
# Afert Tokenizing:  ['এটি', 'সাধারণ', 'নয়', 'তাই', 'এটি', 'প্রদর্শনের', 'জন্য', 'ভাল']
# Truncating punctuation: ['এটি', 'সাধারণ', 'নয়', 'তাই', 'এটি', 'প্রদর্শনের', 'জন্য', 'ভাল']
# Truncating StopWords: ['নয়', 'প্রদর্শনের', 'ভাল']
# 2
# 1
# 16
# ***************************************************************************************
# Label:  1
# Sentence:  অনেক ভাল ছিল দারাজ এবং ডেলিভারি বয় কে ধন্যবাদ
# Afert Tokenizing:  ['অনেক', 'ভাল', 'ছিল', 'দারাজ', 'এবং', 'ডেলিভারি', 'বয়', 'কে', 'ধন্যবাদ']
# Truncating punctuation: ['অনেক', 'ভাল', 'ছিল', 'দারাজ', 'এবং', 'ডেলিভারি', 'বয়', 'কে', 'ধন্যবাদ']
# Truncating StopWords: ['ভাল', 'দারাজ', 'ডেলিভারি', 'বয়', 'ধন্যবাদ']
# 17
# 10
# 4
# 1
# 16
# ***************************************************************************************
# Label:  1
# Sentence:  প্রোডাক্টটি খুব ভাল ছিল আমার পছন্দ হয়েছে
# Afert Tokenizing:  ['প্রোডাক্টটি', 'খুব', 'ভাল', 'ছিল', 'আমার', 'পছন্দ', 'হয়েছে']
# Truncating punctuation: ['প্রোডাক্টটি', 'খুব', 'ভাল', 'ছিল', 'আমার', 'পছন্দ', 'হয়েছে']
# Truncating StopWords: ['প্রোডাক্টটি', 'ভাল', 'পছন্দ']
# 2
# 18
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  আমি এই পণ্য নিয়ে সত্যিই সন্তুষ্ট
# Afert Tokenizing:  ['আমি', 'এই', 'পণ্য', 'নিয়ে', 'সত্যিই', 'সন্তুষ্ট']
# Truncating punctuation: ['আমি', 'এই', 'পণ্য', 'নিয়ে', 'সত্যিই', 'সন্তুষ্ট']
# Truncating StopWords: ['পণ্য', 'সত্যিই', 'সন্তুষ্ট']
# 12
# 2
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  খুব ভাল জিনিস
# Afert Tokenizing:  ['খুব', 'ভাল', 'জিনিস']
# Truncating punctuation: ['খুব', 'ভাল', 'জিনিস']
# Truncating StopWords: ['ভাল', 'জিনিস']
# 19
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  নিতে পারেন
# Afert Tokenizing:  ['নিতে', 'পারেন']
# Truncating punctuation: ['নিতে', 'পারেন']
# Truncating StopWords: []
# ***************************************************************************************
# Label:  -1
# Sentence:  বেশি ভালো না মুটামুটি প্লাস্টিকের বডি
# Afert Tokenizing:  ['বেশি', 'ভালো', 'না', 'মুটামুটি', 'প্লাস্টিকের', 'বডি']
# Truncating punctuation: ['বেশি', 'ভালো', 'না', 'মুটামুটি', 'প্লাস্টিকের', 'বডি']
# Truncating StopWords: ['বেশি', 'ভালো', 'না', 'মুটামুটি', 'প্লাস্টিকের', 'বডি']
# 3
# 37
# 10
# 1
# 2
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  সব ঠিক পাইছি। পন্যটি ভালো। ধন্যবাদ
# Afert Tokenizing:  ['সব', 'ঠিক', 'পাইছি', '।', 'পন্যটি', 'ভালো', '।', 'ধন্যবাদ']
# Truncating punctuation: ['সব', 'ঠিক', 'পাইছি', 'পন্যটি', 'ভালো', 'ধন্যবাদ']
# Truncating StopWords: ['ঠিক', 'পাইছি', 'পন্যটি', 'ভালো', 'ধন্যবাদ']
# 4
# 1
# 1
# 38
# 17
# ***************************************************************************************
# Label:  -1
# Sentence:  খুব খারাপ কাজ করে না
# Afert Tokenizing:  ['খুব', 'খারাপ', 'কাজ', 'করে', 'না']
# Truncating punctuation: ['খুব', 'খারাপ', 'কাজ', 'করে', 'না']
# Truncating StopWords: ['খারাপ', 'না']
# 1
# 11
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল পণ্য আমি সন্তুষ্ট
# Afert Tokenizing:  ['ভাল', 'পণ্য', 'আমি', 'সন্তুষ্ট']
# Truncating punctuation: ['ভাল', 'পণ্য', 'আমি', 'সন্তুষ্ট']
# Truncating StopWords: ['ভাল', 'পণ্য', 'সন্তুষ্ট']
# 20
# 13
# 3
# ***************************************************************************************
# Label:  1
# Sentence:  খুবই ভালো মানের প্রোডাক্ট
# Afert Tokenizing:  ['খুবই', 'ভালো', 'মানের', 'প্রোডাক্ট']
# Truncating punctuation: ['খুবই', 'ভালো', 'মানের', 'প্রোডাক্ট']
# Truncating StopWords: ['খুবই', 'ভালো', 'মানের', 'প্রোডাক্ট']
# 4
# 39
# 1
# 7
# ***************************************************************************************
# Label:  1
# Sentence:  ধাতব ফিনিস ভাল মানের
# Afert Tokenizing:  ['ধাতব', 'ফিনিস', 'ভাল', 'মানের']
# Truncating punctuation: ['ধাতব', 'ফিনিস', 'ভাল', 'মানের']
# Truncating StopWords: ['ধাতব', 'ফিনিস', 'ভাল', 'মানের']
# 1
# 1
# 21
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  খুব ভাল পণ্য। ধন্যবাদ
# Afert Tokenizing:  ['খুব', 'ভাল', 'পণ্য', '।', 'ধন্যবাদ']
# Truncating punctuation: ['খুব', 'ভাল', 'পণ্য', 'ধন্যবাদ']
# Truncating StopWords: ['ভাল', 'পণ্য', 'ধন্যবাদ']
# 22
# 14
# 18
# ***************************************************************************************
# Label:  1
# Sentence:  ভাই জিনিস অনেক সুন্দর
# Afert Tokenizing:  ['ভাই', 'জিনিস', 'অনেক', 'সুন্দর']
# Truncating punctuation: ['ভাই', 'জিনিস', 'অনেক', 'সুন্দর']
# Truncating StopWords: ['ভাই', 'জিনিস', 'সুন্দর']
# 1
# 5
# 6
# ***************************************************************************************
# Label:  1
# Sentence:  খুব খুব ভাল পণ্য
# Afert Tokenizing:  ['খুব', 'খুব', 'ভাল', 'পণ্য']
# Truncating punctuation: ['খুব', 'খুব', 'ভাল', 'পণ্য']
# Truncating StopWords: ['ভাল', 'পণ্য']
# 23
# 15
# ***************************************************************************************
# Label:  1
# Sentence:  মোটামুটি মানের ভালো
# Afert Tokenizing:  ['মোটামুটি', 'মানের', 'ভালো']
# Truncating punctuation: ['মোটামুটি', 'মানের', 'ভালো']
# Truncating StopWords: ['মোটামুটি', 'মানের', 'ভালো']
# 1
# 3
# 40
# ***************************************************************************************
# Label:  1
# Sentence:  সবাই এটা কিনতে পারেন
# Afert Tokenizing:  ['সবাই', 'এটা', 'কিনতে', 'পারেন']
# Truncating punctuation: ['সবাই', 'এটা', 'কিনতে', 'পারেন']
# Truncating StopWords: ['সবাই', 'কিনতে']
# 5
# 7
# ***************************************************************************************
# Label:  1
# Sentence:  সুন্দর আমার এই পণ্য পছন্দ
# Afert Tokenizing:  ['সুন্দর', 'আমার', 'এই', 'পণ্য', 'পছন্দ']
# Truncating punctuation: ['সুন্দর', 'আমার', 'এই', 'পণ্য', 'পছন্দ']
# Truncating StopWords: ['সুন্দর', 'পণ্য', 'পছন্দ']
# 7
# 16
# 3
# ***************************************************************************************
# Label:  1
# Sentence:  অসাধারন
# Afert Tokenizing:  ['অসাধারন']
# Truncating punctuation: ['অসাধারন']
# Truncating StopWords: ['অসাধারন']
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  গুণমান ভাল না
# Afert Tokenizing:  ['গুণমান', 'ভাল', 'না']
# Truncating punctuation: ['গুণমান', 'ভাল', 'না']
# Truncating StopWords: ['গুণমান', 'ভাল', 'না']
# 1
# 24
# 12
# ***************************************************************************************
# Label:  1
# Sentence:  আমি সন্তুষ্ট
# Afert Tokenizing:  ['আমি', 'সন্তুষ্ট']
# Truncating punctuation: ['আমি', 'সন্তুষ্ট']
# Truncating StopWords: ['সন্তুষ্ট']
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  অনেক ভাল মানের
# Afert Tokenizing:  ['অনেক', 'ভাল', 'মানের']
# Truncating punctuation: ['অনেক', 'ভাল', 'মানের']
# Truncating StopWords: ['ভাল', 'মানের']
# 25
# 4
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল পণ্য
# Afert Tokenizing:  ['ভাল', 'পণ্য']
# Truncating punctuation: ['ভাল', 'পণ্য']
# Truncating StopWords: ['ভাল', 'পণ্য']
# 26
# 17
# ***************************************************************************************
# Label:  1
# Sentence:  খুব ভালো
# Afert Tokenizing:  ['খুব', 'ভালো']
# Truncating punctuation: ['খুব', 'ভালো']
# Truncating StopWords: ['ভালো']
# 41
# ***************************************************************************************
# Label:  1
# Sentence:  ভালোই
# Afert Tokenizing:  ['ভালোই']
# Truncating punctuation: ['ভালোই']
# Truncating StopWords: ['ভালোই']
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল
# Afert Tokenizing:  ['ভাল']
# Truncating punctuation: ['ভাল']
# Truncating StopWords: ['ভাল']
# 27
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল
# Afert Tokenizing:  ['ভাল']
# Truncating punctuation: ['ভাল']
# Truncating StopWords: ['ভাল']
# 28
# ***************************************************************************************
# Label:  1
# Sentence:  প্রোডাক্ট ভাল
# Afert Tokenizing:  ['প্রোডাক্ট', 'ভাল']
# Truncating punctuation: ['প্রোডাক্ট', 'ভাল']
# Truncating StopWords: ['প্রোডাক্ট', 'ভাল']
# 8
# 29
# ***************************************************************************************
# Label:  -1
# Sentence:  দারাজের ডেলিভারি ম্যান অনেক ফালতু
# Afert Tokenizing:  ['দারাজের', 'ডেলিভারি', 'ম্যান', 'অনেক', 'ফালতু']
# Truncating punctuation: ['দারাজের', 'ডেলিভারি', 'ম্যান', 'অনেক', 'ফালতু']
# Truncating StopWords: ['দারাজের', 'ডেলিভারি', 'ম্যান', 'ফালতু']
# 1
# 5
# 1
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  আমি অপারেশন এর রুগী আমার বাসার নিচে এসে আমাকে বলে প্রোডাক্ট নিয়ে যেতে
# Afert Tokenizing:  ['আমি', 'অপারেশন', 'এর', 'রুগী', 'আমার', 'বাসার', 'নিচে', 'এসে', 'আমাকে', 'বলে', 'প্রোডাক্ট', 'নিয়ে', 'যেতে']
# Truncating punctuation: ['আমি', 'অপারেশন', 'এর', 'রুগী', 'আমার', 'বাসার', 'নিচে', 'এসে', 'আমাকে', 'বলে', 'প্রোডাক্ট', 'নিয়ে', 'যেতে']
# Truncating StopWords: ['অপারেশন', 'রুগী', 'বাসার', 'নিচে', 'প্রোডাক্ট']
# 1
# 1
# 1
# 1
# 9
# ***************************************************************************************
# Label:  -1
# Sentence:  আমি বললাম ভাই আমাকে একটু যদি উপরে দিয়ে যেতেন তাহলে ভাল হতো কিন্তু সে দিয়ে গেল না
# Afert Tokenizing:  ['আমি', 'বললাম', 'ভাই', 'আমাকে', 'একটু', 'যদি', 'উপরে', 'দিয়ে', 'যেতেন', 'তাহলে', 'ভাল', 'হতো', 'কিন্তু', 'সে', 'দিয়ে', 'গেল', 'না']
# Truncating punctuation: ['আমি', 'বললাম', 'ভাই', 'আমাকে', 'একটু', 'যদি', 'উপরে', 'দিয়ে', 'যেতেন', 'তাহলে', 'ভাল', 'হতো', 'কিন্তু', 'সে', 'দিয়ে', 'গেল', 'না']
# Truncating StopWords: ['বললাম', 'ভাই', 'একটু', 'দিয়ে', 'যেতেন', 'ভাল', 'হতো', 'দিয়ে', 'না']
# 1
# 2
# 1
# 1
# 1
# 30
# 2
# 2
# 13
# ***************************************************************************************
# Label:  -1
# Sentence:  দাম অনুযায়ী কুয়ালিটি ঠিক নাই কুয়ালিটি
# Afert Tokenizing:  ['দাম', 'অনুযায়ী', 'কুয়ালিটি', 'ঠিক', 'নাই', 'কুয়ালিটি']
# Truncating punctuation: ['দাম', 'অনুযায়ী', 'কুয়ালিটি', 'ঠিক', 'নাই', 'কুয়ালিটি']
# Truncating StopWords: ['দাম', 'অনুযায়ী', 'কুয়ালিটি', 'ঠিক', 'নাই', 'কুয়ালিটি']
# 4
# 1
# 1
# 5
# 2
# 2
# ***************************************************************************************
# Label:  0
# Sentence:  কুয়ালিটি আরেকটু ভালো দরকার ছিলো
# Afert Tokenizing:  ['কুয়ালিটি', 'আরেকটু', 'ভালো', 'দরকার', 'ছিলো']
# Truncating punctuation: ['কুয়ালিটি', 'আরেকটু', 'ভালো', 'দরকার', 'ছিলো']
# Truncating StopWords: ['কুয়ালিটি', 'আরেকটু', 'ভালো', 'দরকার', 'ছিলো']
# 3
# 2
# 42
# 1
# 3
# ***************************************************************************************
# Label:  0
# Sentence:  এমনি তে ঠিক আছে দেখি কতদিন ব্যবহার করতে পারি
# Afert Tokenizing:  ['এমনি', 'তে', 'ঠিক', 'আছে', 'দেখি', 'কতদিন', 'ব্যবহার', 'করতে', 'পারি']
# Truncating punctuation: ['এমনি', 'তে', 'ঠিক', 'আছে', 'দেখি', 'কতদিন', 'ব্যবহার', 'করতে', 'পারি']
# Truncating StopWords: ['তে', 'ঠিক', 'দেখি', 'কতদিন']
# 1
# 6
# 1
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  মান খারাপ
# Afert Tokenizing:  ['মান', 'খারাপ']
# Truncating punctuation: ['মান', 'খারাপ']
# Truncating StopWords: ['মান', 'খারাপ']
# 2
# 2
# ***************************************************************************************
# Label:  -1
# Sentence:  আমি এটি শুধুমাত্র দুবার ব্যবহার করেছি এবং এটি খারাপ হয়ে গেছে
# Afert Tokenizing:  ['আমি', 'এটি', 'শুধুমাত্র', 'দুবার', 'ব্যবহার', 'করেছি', 'এবং', 'এটি', 'খারাপ', 'হয়ে', 'গেছে']
# Truncating punctuation: ['আমি', 'এটি', 'শুধুমাত্র', 'দুবার', 'ব্যবহার', 'করেছি', 'এবং', 'এটি', 'খারাপ', 'হয়ে', 'গেছে']
# Truncating StopWords: ['শুধুমাত্র', 'দুবার', 'করেছি', 'খারাপ']
# 2
# 1
# 1
# 3
# ***************************************************************************************
# Label:  -1
# Sentence:  সম্পূর্ণ ক্ষতি বিনিয়োগ
# Afert Tokenizing:  ['সম্পূর্ণ', 'ক্ষতি', 'বিনিয়োগ']
# Truncating punctuation: ['সম্পূর্ণ', 'ক্ষতি', 'বিনিয়োগ']
# Truncating StopWords: ['সম্পূর্ণ', 'ক্ষতি', 'বিনিয়োগ']
# 1
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  খুব সুন্দর পণ্য
# Afert Tokenizing:  ['খুব', 'সুন্দর', 'পণ্য']
# Truncating punctuation: ['খুব', 'সুন্দর', 'পণ্য']
# Truncating StopWords: ['সুন্দর', 'পণ্য']
# 8
# 18
# ***************************************************************************************
# Label:  1
# Sentence:  সস্তা দাম ভাল পণ্য
# Afert Tokenizing:  ['সস্তা', 'দাম', 'ভাল', 'পণ্য']
# Truncating punctuation: ['সস্তা', 'দাম', 'ভাল', 'পণ্য']
# Truncating StopWords: ['সস্তা', 'দাম', 'ভাল', 'পণ্য']
# 1
# 5
# 31
# 19
# ***************************************************************************************
# Label:  1
# Sentence:  বিক্রেতা এছাড়াও ভাল
# Afert Tokenizing:  ['বিক্রেতা', 'এছাড়াও', 'ভাল']
# Truncating punctuation: ['বিক্রেতা', 'এছাড়াও', 'ভাল']
# Truncating StopWords: ['বিক্রেতা', 'এছাড়াও', 'ভাল']
# 3
# 1
# 32
# ***************************************************************************************
# Label:  1
# Sentence:  দাম বিবেচনা করে, এটি ভাল
# Afert Tokenizing:  ['দাম', 'বিবেচনা', 'করে', ',', 'এটি', 'ভাল']
# Truncating punctuation: ['দাম', 'বিবেচনা', 'করে', 'এটি', 'ভাল']
# Truncating StopWords: ['দাম', 'বিবেচনা', 'ভাল']
# 6
# 1
# 33
# ***************************************************************************************
# Label:  0
# Sentence:  বিল্ড কোয়ালিটি ভালো হতে পারে।
# Afert Tokenizing:  ['বিল্ড', 'কোয়ালিটি', 'ভালো', 'হতে', 'পারে', '।']
# Truncating punctuation: ['বিল্ড', 'কোয়ালিটি', 'ভালো', 'হতে', 'পারে']
# Truncating StopWords: ['বিল্ড', 'কোয়ালিটি', 'ভালো']
# 1
# 1
# 43
# ***************************************************************************************
# Label:  1
# Sentence:  হুম লাইটার টা ভালোই লেগেছে আমার কাছে এটা খুব সুন্দর একটি লাইটার।
# Afert Tokenizing:  ['হুম', 'লাইটার', 'টা', 'ভালোই', 'লেগেছে', 'আমার', 'কাছে', 'এটা', 'খুব', 'সুন্দর', 'একটি', 'লাইটার', '।']
# Truncating punctuation: ['হুম', 'লাইটার', 'টা', 'ভালোই', 'লেগেছে', 'আমার', 'কাছে', 'এটা', 'খুব', 'সুন্দর', 'একটি', 'লাইটার']
# Truncating StopWords: ['হুম', 'লাইটার', 'টা', 'ভালোই', 'লেগেছে', 'সুন্দর', 'লাইটার']
# 1
# 7
# 10
# 2
# 1
# 9
# 8
# ***************************************************************************************
# Label:  0
# Sentence:  আমি একজনকে গিফট করছিলাম
# Afert Tokenizing:  ['আমি', 'একজনকে', 'গিফট', 'করছিলাম']
# Truncating punctuation: ['আমি', 'একজনকে', 'গিফট', 'করছিলাম']
# Truncating StopWords: ['একজনকে', 'গিফট', 'করছিলাম']
# 1
# 1
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  জিনিসটা আসলেই ভালো হইছে
# Afert Tokenizing:  ['জিনিসটা', 'আসলেই', 'ভালো', 'হইছে']
# Truncating punctuation: ['জিনিসটা', 'আসলেই', 'ভালো', 'হইছে']
# Truncating StopWords: ['জিনিসটা', 'আসলেই', 'ভালো', 'হইছে']
# 2
# 1
# 44
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  তার পছন্দ হইছে
# Afert Tokenizing:  ['তার', 'পছন্দ', 'হইছে']
# Truncating punctuation: ['তার', 'পছন্দ', 'হইছে']
# Truncating StopWords: ['পছন্দ', 'হইছে']
# 4
# 2
# ***************************************************************************************
# Label:  -1
# Sentence:  দুইটা লাইট ওয়ার্ডার করছিলাম। একটা ভালো দিছে একটা নষ্ট।
# Afert Tokenizing:  ['দুইটা', 'লাইট', 'ওয়ার্ডার', 'করছিলাম', '।', 'একটা', 'ভালো', 'দিছে', 'একটা', 'নষ্ট', '।']
# Truncating punctuation: ['দুইটা', 'লাইট', 'ওয়ার্ডার', 'করছিলাম', 'একটা', 'ভালো', 'দিছে', 'একটা', 'নষ্ট']
# Truncating StopWords: ['দুইটা', 'লাইট', 'ওয়ার্ডার', 'করছিলাম', 'একটা', 'ভালো', 'দিছে', 'একটা', 'নষ্ট']
# 1
# 2
# 1
# 3
# 9
# 45
# 1
# 10
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  আলহামদুলিল্লাহ প্রোডাক্ট খুব ভালো। যে কেউ এটি কিনতে পারেন
# Afert Tokenizing:  ['আলহামদুলিল্লাহ', 'প্রোডাক্ট', 'খুব', 'ভালো', '।', 'যে', 'কেউ', 'এটি', 'কিনতে', 'পারেন']
# Truncating punctuation: ['আলহামদুলিল্লাহ', 'প্রোডাক্ট', 'খুব', 'ভালো', 'যে', 'কেউ', 'এটি', 'কিনতে', 'পারেন']
# Truncating StopWords: ['আলহামদুলিল্লাহ', 'প্রোডাক্ট', 'ভালো', 'কিনতে']
# 4
# 10
# 46
# 8
# ***************************************************************************************
# Label:  1
# Sentence:  এই দামের জন্য ভাল মানের। বিক্রয়কর্মীর জন্য ধন্যবাদ
# Afert Tokenizing:  ['এই', 'দামের', 'জন্য', 'ভাল', 'মানের', '।', 'বিক্রয়কর্মীর', 'জন্য', 'ধন্যবাদ']
# Truncating punctuation: ['এই', 'দামের', 'জন্য', 'ভাল', 'মানের', 'বিক্রয়কর্মীর', 'জন্য', 'ধন্যবাদ']
# Truncating StopWords: ['দামের', 'ভাল', 'মানের', 'বিক্রয়কর্মীর', 'ধন্যবাদ']
# 1
# 34
# 5
# 1
# 19
# ***************************************************************************************
# Label:  1
# Sentence:  পণ্য ভাল
# Afert Tokenizing:  ['পণ্য', 'ভাল']
# Truncating punctuation: ['পণ্য', 'ভাল']
# Truncating StopWords: ['পণ্য', 'ভাল']
# 20
# 35
# ***************************************************************************************
# Label:  -1
# Sentence:  প্লাস্টিকের অংশ গলে যাচ্ছে
# Afert Tokenizing:  ['প্লাস্টিকের', 'অংশ', 'গলে', 'যাচ্ছে']
# Truncating punctuation: ['প্লাস্টিকের', 'অংশ', 'গলে', 'যাচ্ছে']
# Truncating StopWords: ['প্লাস্টিকের', 'অংশ', 'গলে']
# 3
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  মোটামুটি ভালো চাইলে আপনারাও নিতে পারেন
# Afert Tokenizing:  ['মোটামুটি', 'ভালো', 'চাইলে', 'আপনারাও', 'নিতে', 'পারেন']
# Truncating punctuation: ['মোটামুটি', 'ভালো', 'চাইলে', 'আপনারাও', 'নিতে', 'পারেন']
# Truncating StopWords: ['মোটামুটি', 'ভালো', 'চাইলে', 'আপনারাও']
# 2
# 47
# 10
# 2
# ***************************************************************************************
# Label:  -1
# Sentence:  খারাপ পণ্য। প্রথম দিন ব্যবহার করার সময় ক্ষতিগ্রস্ত হয়েছে
# Afert Tokenizing:  ['খারাপ', 'পণ্য', '।', 'প্রথম', 'দিন', 'ব্যবহার', 'করার', 'সময়', 'ক্ষতিগ্রস্ত', 'হয়েছে']
# Truncating punctuation: ['খারাপ', 'পণ্য', 'প্রথম', 'দিন', 'ব্যবহার', 'করার', 'সময়', 'ক্ষতিগ্রস্ত', 'হয়েছে']
# Truncating StopWords: ['খারাপ', 'পণ্য', 'সময়', 'ক্ষতিগ্রস্ত']
# 4
# 21
# 1
# 1
# ***************************************************************************************
# Label:  -1
# Sentence:  খারাপ
# Afert Tokenizing:  ['খারাপ']
# Truncating punctuation: ['খারাপ']
# Truncating StopWords: ['খারাপ']
# 5
# ***************************************************************************************
# Label:  1
# Sentence:  আশা করি ভালো লাগবে, ব্যবহার করে দেখা যাক
# Afert Tokenizing:  ['আশা', 'করি', 'ভালো', 'লাগবে', ',', 'ব্যবহার', 'করে', 'দেখা', 'যাক']
# Truncating punctuation: ['আশা', 'করি', 'ভালো', 'লাগবে', 'ব্যবহার', 'করে', 'দেখা', 'যাক']
# Truncating StopWords: ['আশা', 'ভালো', 'লাগবে', 'যাক']
# 2
# 48
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  ভালো ছিল
# Afert Tokenizing:  ['ভালো', 'ছিল']
# Truncating punctuation: ['ভালো', 'ছিল']
# Truncating StopWords: ['ভালো']
# 49
# ***************************************************************************************
# Label:  1
# Sentence:  ভালো
# Afert Tokenizing:  ['ভালো']
# Truncating punctuation: ['ভালো']
# Truncating StopWords: ['ভালো']
# 50
# ***************************************************************************************
# Label:  1
# Sentence:  চমৎকার
# Afert Tokenizing:  ['চমৎকার']
# Truncating punctuation: ['চমৎকার']
# Truncating StopWords: ['চমৎকার']
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  ধন্যবাদ বিক্রেতা আমাকে একটি ভাল লাইটার দিয়েছেন
# Afert Tokenizing:  ['ধন্যবাদ', 'বিক্রেতা', 'আমাকে', 'একটি', 'ভাল', 'লাইটার', 'দিয়েছেন']
# Truncating punctuation: ['ধন্যবাদ', 'বিক্রেতা', 'আমাকে', 'একটি', 'ভাল', 'লাইটার', 'দিয়েছেন']
# Truncating StopWords: ['ধন্যবাদ', 'বিক্রেতা', 'ভাল', 'লাইটার']
# 20
# 4
# 36
# 9
# ***************************************************************************************
# Label:  0
# Sentence:  দেখা যাক কতদিন ব্যবহার করা যায়
# Afert Tokenizing:  ['দেখা', 'যাক', 'কতদিন', 'ব্যবহার', 'করা', 'যায়']
# Truncating punctuation: ['দেখা', 'যাক', 'কতদিন', 'ব্যবহার', 'করা', 'যায়']
# Truncating StopWords: ['যাক', 'কতদিন']
# 2
# 2
# ***************************************************************************************
# Label:  0
# Sentence:  পণ্য দিয়েছে
# Afert Tokenizing:  ['পণ্য', 'দিয়েছে']
# Truncating punctuation: ['পণ্য', 'দিয়েছে']
# Truncating StopWords: ['পণ্য', 'দিয়েছে']
# 22
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  খুব সুন্দর পণ্য
# Afert Tokenizing:  ['খুব', 'সুন্দর', 'পণ্য']
# Truncating punctuation: ['খুব', 'সুন্দর', 'পণ্য']
# Truncating StopWords: ['সুন্দর', 'পণ্য']
# 10
# 23
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল জিনিস,সবাই নিতে পারেন
# Afert Tokenizing:  ['ভাল', 'জিনিস,সবাই', 'নিতে', 'পারেন']
# Truncating punctuation: ['ভাল', 'জিনিস,সবাই', 'নিতে', 'পারেন']
# Truncating StopWords: ['ভাল', 'জিনিস,সবাই']
# 37
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  যেমন চাইসি তেমনই পাইসি
# Afert Tokenizing:  ['যেমন', 'চাইসি', 'তেমনই', 'পাইসি']
# Truncating punctuation: ['যেমন', 'চাইসি', 'তেমনই', 'পাইসি']
# Truncating StopWords: ['চাইসি', 'তেমনই', 'পাইসি']
# 1
# 1
# 1
# ***************************************************************************************
# Label:  1
# Sentence:  খুবই ভালো একটা জিনিস
# Afert Tokenizing:  ['খুবই', 'ভালো', 'একটা', 'জিনিস']
# Truncating punctuation: ['খুবই', 'ভালো', 'একটা', 'জিনিস']
# Truncating StopWords: ['খুবই', 'ভালো', 'একটা', 'জিনিস']
# 5
# 51
# 11
# 6
# ***************************************************************************************
# Label:  1
# Sentence:  ভালো নিতে পারেন সবাই
# Afert Tokenizing:  ['ভালো', 'নিতে', 'পারেন', 'সবাই']
# Truncating punctuation: ['ভালো', 'নিতে', 'পারেন', 'সবাই']
# Truncating StopWords: ['ভালো', 'সবাই']
# 52
# 6
# ***************************************************************************************
# Label:  1
# Sentence:  খুব ভালো হয়েছে
# Afert Tokenizing:  ['খুব', 'ভালো', 'হয়েছে']
# Truncating punctuation: ['খুব', 'ভালো', 'হয়েছে']
# Truncating StopWords: ['ভালো', 'হয়েছে']
# 53
# 2
# ***************************************************************************************
# Label:  1
# Sentence:  খুব ভালো হয়েছে
# Afert Tokenizing:  ['খুব', 'ভালো', 'হয়েছে']
# Truncating punctuation: ['খুব', 'ভালো', 'হয়েছে']
# Truncating StopWords: ['ভালো', 'হয়েছে']
# 54
# 3
# ***************************************************************************************
# Label:  1
# Sentence:  চমৎকার পণ্য
# Afert Tokenizing:  ['চমৎকার', 'পণ্য']
# Truncating punctuation: ['চমৎকার', 'পণ্য']
# Truncating StopWords: ['চমৎকার', 'পণ্য']
# 3
# 24
# ***************************************************************************************
# Label:  1
# Sentence:  ভালো জিনিস
# Afert Tokenizing:  ['ভালো', 'জিনিস']
# Truncating punctuation: ['ভালো', 'জিনিস']
# Truncating StopWords: ['ভালো', 'জিনিস']
# 55
# 7
# ***************************************************************************************
# Label:  1
# Sentence:  ভাল পণ্য
# Afert Tokenizing:  ['ভাল', 'পণ্য']
# Truncating punctuation: ['ভাল', 'পণ্য']
# Truncating StopWords: ['ভাল', 'পণ্য']
# 38
# 25
# ***************************************************************************************
# Label:  1
# Sentence:  খুব ভালো
# Afert Tokenizing:  ['খুব', 'ভালো']
# Truncating punctuation: ['খুব', 'ভালো']
# Truncating StopWords: ['ভালো']
# 56
# ***************************************************************************************
# Label:  1
# Sentence:  ভালো
# Afert Tokenizing:  ['ভালো']
# Truncating punctuation: ['ভালো']
# Truncating StopWords: ['ভালো']
# 57
# ***************************************************************************************

# %%
xs
# Out:
# ['ভালো প্রোডাক্ট পেয়েছি ধন্যবাদ দারাজ ধন্যবাদ ডেলিভারি বয় এন্ড ইউজ আরো ভালো লাগছে অন্যেরাও কিনতে আপনাদের পূর্ণ ভালো',
#  'আপনাদের ডেলিভারি মেন ভালো',
#  'তাড়াতাড়ি পণ্য গেলাম,ধন্যবাদ',
#  'একদম ভাল না সবিতে যেরকম সিলো না পুরান',
#  'রিটান দিলে নেয়না',
#  'নিতাম না',
#  'নিবেন না',
#  'অল্প টাকায় প্রডাক্ট টা ভালো',
#  'বিড়ি খোর দের দরকারি একটা প্রডাক্ট চাইলে',
#  'সেলারের ভালো ছিলো',
#  'ধন্যবাদ দারাজ',
#  'লাইটার টা সুন্দর',
#  'ব্যাটারি ক্যাপাসিটি আরেকটু বেশি ভালো হতো দাম ঠিক',
#  'একটা কথা না বললেই নয় প্যাকেটটা একদম ইনটেক দারাজ সেলারকে ধন্যবাদ',
#  'অল দ্যা বেস্ট দারাজ',
#  'অল্প টাকায় প্রডাক্ট টা ভালো',
#  'সেলারের ভালো ছিলো',
#  'ভালো প্রডাক্ট চাইলে আপনারা কিনতে',
#  'আলহামদুলিল্লাহ প্রোডাক্ট টা খুবই ভালো',
#  'আলহামদুলিল্লাহ ভালো প্রোডাক্টটা ভালো চার্জ ভালো ভালো আপনারা চাইলে',
#  'সেলার ভাইকে ধন্যবাদ কারন পন্য বাসাত ঠিক দেয়ার',
#  'ভালো আপনারা',
#  'জিনিস টা খুপ ভালো আপনারা চাইলে',
#  'ভাল সবাই',
#  'টা অর্ডার করছিলাম ঠিক তেমনটাই পেয়েছি ধন্যবাদ দার আজকে ধন্যবাদ ছেলের',
#  'কম দামে জিনিস টা ভালো',
#  'আপনেও চাইলে কিনতে সমস্যা নাই',
#  'ভালো লাগসে',
#  'সুন্দর একটা লাইটার',
#  '১৬৫ টাকা হিসেবে ভাল পরেছে',
#  'দুর্দান্ত পণ্য',
#  'পোর্টেবল লাইটার কিনতে',
#  'ছবির মত',
#  'মাঝামাঝি ধরন পণ্য',
#  'শুধুমাত্র মজার অর্ডার করুন',
#  'ভালো একটা প্রোর্ডাকট প্রথমে ভাবেছিলা ভালো না দেখলাম চেয়েছি ভালো পেয়েছি আপনারা চাইলে ধন্যবাদ দারাজ ডেলিভারি মেন',
#  'যেরকম চেয়েছিলাম আলহামদুলিল্লাহ ভালো পেয়েছি দারাজ দারুন শপিং মার্কেট আপনারা চাইলে কিনতে',
#  'ভাল পণ্য',
#  'ভালো বিক্রেতা',
#  'ভাল প্রাণঘাতী',
#  'সন্তুষ্ট',
#  'পণ্য ১০/১০',
#  'চার্জ দিনের',
#  'একদম লাইট ওয়েট',
#  'পাশে পাতলা',
#  'ভালো আশা দারাজ সাথে থাকুন',
#  'জিনিস টা ভালো',
#  'আপনারাও',
#  'প্লাস্টিকের তৈরি সূক্ষ্ম',
#  'খুবই ভালো একটা প্রডাক্ট',
#  'ব্যাবহার একদম সহজ বাতাসেও নিভে যাওয়ার ভয় নেই',
#  "ধন্যবাদ জানায় দারাজ'কে এনাদের যুক্ত সকলকে ধন্যবাদ",
#  'দাম হিসেবে ভালো একটা লাইটার আপনারা চাইলে',
#  'বেশি ভালো একটা প্রডাক্ট',
#  'চাইলে সবাই',
#  'ভালো লাগছে',
#  'ধন্যবাদ',
#  'চিন্তার চেয়েও ভালো',
#  'ভাল পণ্য বিক্রেতাকে ধন্যবাদ',
#  'ধন্যবাদ সেলার প্রডাক্ট টা আসলে ভালো সবাই',
#  'ভাল পণ্য',
#  'লাইটার পেয়েছি চার্জার নেই',
#  'দারাজ ভালো একটা পণ্য পেলাম',
#  'চার্জ না রিটার্ন করলাম',
#  'দাম বিবেচনায় জিনিসটা ভালো',
#  'সুন্দর প্রোডাক্টটি',
#  'দারুন প্রডাক্ট',
#  'ভাল পণ্য',
#  'সুন্দর প্রোডাক্ট পচ্ছন্দ হয়েছে দারাজকে ধন্যবাদ সুন্দর প্রোডাক্ট দেবার',
#  'প্রডাক্ট ভাল ভাল বন্দুরা',
#  'বেসি ভাল না ছবির মত ভাল না বাস্তবে',
#  'পণ্য পাইনি',
#  'লাইটার জ্বালিয়ে রাখলে গরম খুবই অল্প সময়ের ভিতরে অতিরিক্ত হিট',
#  'প্রোডাক্ট মানে ভালো নিঃসন্দেহে কিনতে দ্বিতীয় অর্ডার',
#  'ভাল',
#  'পণ্যটি ভাল পেয়েছি',
#  'বিক্রেতা ভাল',
#  'ধন্যবাদ দারাজ',
#  'প্রোডাক্ট মান ভালো তৃতীয় অর্ডার সবাই',
#  'দামে চমৎকার পণ্য',
#  'সত্যিই সিস্টেম পছন্দ',
#  'নয় প্রদর্শনের ভাল',
#  'ভাল দারাজ ডেলিভারি বয় ধন্যবাদ',
#  'প্রোডাক্টটি ভাল পছন্দ',
#  'পণ্য সত্যিই সন্তুষ্ট',
#  'ভাল জিনিস',
#  '',
#  'বেশি ভালো না মুটামুটি প্লাস্টিকের বডি',
#  'ঠিক পাইছি পন্যটি ভালো ধন্যবাদ',
#  'খারাপ না',
#  'ভাল পণ্য সন্তুষ্ট',
#  'খুবই ভালো মানের প্রোডাক্ট',
#  'ধাতব ফিনিস ভাল মানের',
#  'ভাল পণ্য ধন্যবাদ',
#  'ভাই জিনিস সুন্দর',
#  'ভাল পণ্য',
#  'মোটামুটি মানের ভালো',
#  'সবাই কিনতে',
#  'সুন্দর পণ্য পছন্দ',
#  'অসাধারন',
#  'গুণমান ভাল না',
#  'সন্তুষ্ট',
#  'ভাল মানের',
#  'ভাল পণ্য',
#  'ভালো',
#  'ভালোই',
#  'ভাল',
#  'ভাল',
#  'প্রোডাক্ট ভাল',
#  'দারাজের ডেলিভারি ম্যান ফালতু',
#  'অপারেশন রুগী বাসার নিচে প্রোডাক্ট',
#  'বললাম ভাই একটু দিয়ে যেতেন ভাল হতো দিয়ে না',
#  'দাম অনুযায়ী কুয়ালিটি ঠিক নাই কুয়ালিটি',
#  'কুয়ালিটি আরেকটু ভালো দরকার ছিলো',
#  'তে ঠিক দেখি কতদিন',
#  'মান খারাপ',
#  'শুধুমাত্র দুবার করেছি খারাপ',
#  'সম্পূর্ণ ক্ষতি বিনিয়োগ',
#  'সুন্দর পণ্য',
#  'সস্তা দাম ভাল পণ্য',
#  'বিক্রেতা এছাড়াও ভাল',
#  'দাম বিবেচনা ভাল',
#  'বিল্ড কোয়ালিটি ভালো',
#  'হুম লাইটার টা ভালোই লেগেছে সুন্দর লাইটার',
#  'একজনকে গিফট করছিলাম',
#  'জিনিসটা আসলেই ভালো হইছে',
#  'পছন্দ হইছে',
#  'দুইটা লাইট ওয়ার্ডার করছিলাম একটা ভালো দিছে একটা নষ্ট',
#  'আলহামদুলিল্লাহ প্রোডাক্ট ভালো কিনতে',
#  'দামের ভাল মানের বিক্রয়কর্মীর ধন্যবাদ',
#  'পণ্য ভাল',
#  'প্লাস্টিকের অংশ গলে',
#  'মোটামুটি ভালো চাইলে আপনারাও',
#  'খারাপ পণ্য সময় ক্ষতিগ্রস্ত',
#  'খারাপ',
#  'আশা ভালো লাগবে যাক',
#  'ভালো',
#  'ভালো',
#  'চমৎকার',
#  'ধন্যবাদ বিক্রেতা ভাল লাইটার',
#  'যাক কতদিন',
#  'পণ্য দিয়েছে',
#  'সুন্দর পণ্য',
#  'ভাল জিনিস,সবাই',
#  'চাইসি তেমনই পাইসি',
#  'খুবই ভালো একটা জিনিস',
#  'ভালো সবাই',
#  'ভালো হয়েছে',
#  'ভালো হয়েছে',
#  'চমৎকার পণ্য',
#  'ভালো জিনিস',
#  'ভাল পণ্য',
#  'ভালো',
#  'ভালো']

# %% [markdown]
# ##**TF-IDF**

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(xs, ys, test_size=0.25, random_state=0)
Xtrain
# Out:
# ['খুবই ভালো একটা জিনিস',
#  'সেলার ভাইকে ধন্যবাদ কারন পন্য বাসাত ঠিক দেয়ার',
#  'অল্প টাকায় প্রডাক্ট টা ভালো',
#  'প্লাস্টিকের তৈরি সূক্ষ্ম',
#  'বেশি ভালো একটা প্রডাক্ট',
#  'পণ্য পাইনি',
#  'বিক্রেতা ভাল',
#  'খারাপ',
#  'প্লাস্টিকের অংশ গলে',
#  'ভালো একটা প্রোর্ডাকট প্রথমে ভাবেছিলা ভালো না দেখলাম চেয়েছি ভালো পেয়েছি আপনারা চাইলে ধন্যবাদ দারাজ ডেলিভারি মেন',
#  'খুবই ভালো একটা প্রডাক্ট',
#  'চাইলে সবাই',
#  'যেরকম চেয়েছিলাম আলহামদুলিল্লাহ ভালো পেয়েছি দারাজ দারুন শপিং মার্কেট আপনারা চাইলে কিনতে',
#  'চমৎকার পণ্য',
#  'ভালো',
#  'মান খারাপ',
#  'অপারেশন রুগী বাসার নিচে প্রোডাক্ট',
#  'ভালো হয়েছে',
#  'খারাপ পণ্য সময় ক্ষতিগ্রস্ত',
#  'চার্জ না রিটার্ন করলাম',
#  'চার্জ দিনের',
#  'আপনেও চাইলে কিনতে সমস্যা নাই',
#  'অসাধারন',
#  'ভালো প্রোডাক্ট পেয়েছি ধন্যবাদ দারাজ ধন্যবাদ ডেলিভারি বয় এন্ড ইউজ আরো ভালো লাগছে অন্যেরাও কিনতে আপনাদের পূর্ণ ভালো',
#  'কম দামে জিনিস টা ভালো',
#  'ভাল মানের',
#  'চাইসি তেমনই পাইসি',
#  'সেলারের ভালো ছিলো',
#  'শুধুমাত্র মজার অর্ডার করুন',
#  'বিক্রেতা এছাড়াও ভাল',
#  'বিড়ি খোর দের দরকারি একটা প্রডাক্ট চাইলে',
#  'সুন্দর প্রোডাক্টটি',
#  'নিবেন না',
#  'হুম লাইটার টা ভালোই লেগেছে সুন্দর লাইটার',
#  'সত্যিই সিস্টেম পছন্দ',
#  'ভাল পণ্য',
#  'ভালো জিনিস',
#  'একজনকে গিফট করছিলাম',
#  'বিল্ড কোয়ালিটি ভালো',
#  'আশা ভালো লাগবে যাক',
#  'আলহামদুলিল্লাহ প্রোডাক্ট ভালো কিনতে',
#  'প্রোডাক্ট মান ভালো তৃতীয় অর্ডার সবাই',
#  'ভালোই',
#  'যাক কতদিন',
#  'ছবির মত',
#  '',
#  'দারাজ ভালো একটা পণ্য পেলাম',
#  '১৬৫ টাকা হিসেবে ভাল পরেছে',
#  'ভালো লাগসে',
#  'সন্তুষ্ট',
#  'পণ্য ১০/১০',
#  'সম্পূর্ণ ক্ষতি বিনিয়োগ',
#  'ভালো লাগছে',
#  'চমৎকার',
#  'সস্তা দাম ভাল পণ্য',
#  'লাইটার পেয়েছি চার্জার নেই',
#  'ব্যাবহার একদম সহজ বাতাসেও নিভে যাওয়ার ভয় নেই',
#  'ভাল পণ্য',
#  'জিনিস টা খুপ ভালো আপনারা চাইলে',
#  'দাম বিবেচনা ভাল',
#  'ধন্যবাদ দারাজ',
#  'পাশে পাতলা',
#  'দুর্দান্ত পণ্য',
#  'ভাল পণ্য',
#  'আলহামদুলিল্লাহ ভালো প্রোডাক্টটা ভালো চার্জ ভালো ভালো আপনারা চাইলে',
#  'প্রোডাক্টটি ভাল পছন্দ',
#  'পণ্য দিয়েছে',
#  'ভাল পণ্য',
#  'ভাল পণ্য ধন্যবাদ',
#  'ভাল',
#  'প্রডাক্ট ভাল ভাল বন্দুরা',
#  'ধন্যবাদ',
#  'মোটামুটি মানের ভালো',
#  'লাইটার জ্বালিয়ে রাখলে গরম খুবই অল্প সময়ের ভিতরে অতিরিক্ত হিট',
#  'পণ্য ভাল',
#  'ভাল প্রাণঘাতী',
#  'ভাল',
#  'ভালো আপনারা',
#  'মোটামুটি ভালো চাইলে আপনারাও',
#  'সুন্দর পণ্য',
#  'প্রোডাক্ট ভাল',
#  'সুন্দর পণ্য',
#  'কুয়ালিটি আরেকটু ভালো দরকার ছিলো',
#  'ধন্যবাদ সেলার প্রডাক্ট টা আসলে ভালো সবাই',
#  'দারাজের ডেলিভারি ম্যান ফালতু',
#  'ভাল পণ্য সন্তুষ্ট',
#  'ভাল জিনিস',
#  'ভাল সবাই',
#  'দাম বিবেচনায় জিনিসটা ভালো',
#  'দুইটা লাইট ওয়ার্ডার করছিলাম একটা ভালো দিছে একটা নষ্ট',
#  'ভাল পণ্য',
#  'ভাল জিনিস,সবাই',
#  'জিনিস টা ভালো',
#  'ভালো বিক্রেতা',
#  'সুন্দর পণ্য পছন্দ',
#  'সুন্দর প্রোডাক্ট পচ্ছন্দ হয়েছে দারাজকে ধন্যবাদ সুন্দর প্রোডাক্ট দেবার',
#  'চিন্তার চেয়েও ভালো',
#  'শুধুমাত্র দুবার করেছি খারাপ',
#  'দাম অনুযায়ী কুয়ালিটি ঠিক নাই কুয়ালিটি',
#  'একদম লাইট ওয়েট',
#  'একদম ভাল না সবিতে যেরকম সিলো না পুরান',
#  'গুণমান ভাল না',
#  'পোর্টেবল লাইটার কিনতে',
#  'সুন্দর একটা লাইটার',
#  'অল দ্যা বেস্ট দারাজ',
#  'প্রোডাক্ট মানে ভালো নিঃসন্দেহে কিনতে দ্বিতীয় অর্ডার',
#  'ভালো',
#  'সেলারের ভালো ছিলো',
#  'পছন্দ হইছে',
#  'আপনারাও',
#  'ভালো',
#  'ভালো সবাই',
#  'ভাল পণ্য',
#  'দামের ভাল মানের বিক্রয়কর্মীর ধন্যবাদ',
#  'সন্তুষ্ট']

# %%
tfidf = TfidfVectorizer(ngram_range=(1,3),use_idf=True,tokenizer=lambda x: x.split()) 
Xtrain_tf = tfidf.fit_transform(Xtrain)
print("n_samples: %d, n_features: %d" % Xtrain_tf.shape)
# Out:
# n_samples: 115, n_features: 720

# %%
#transforming test data into tf-idf matrix
Xtest_tf = tfidf.transform(Xtest)
print("n_samples: %d, n_features: %d" % Xtest_tf.shape)
# Out:
# n_samples: 39, n_features: 731

# %% [markdown]
# ##**Naive Bayes**

# %%
#naive bayes classifier
from sklearn.naive_bayes import MultinomialNB
naive_bayes_classifier = MultinomialNB()
naive_bayes_classifier.fit(Xtrain_tf, Ytrain)
#predicted y
y_pred = naive_bayes_classifier.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(naive_bayes_classifier , Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Naive Bayes Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[ 1  0  6]
#  [ 0  0  1]
#  [ 0  0 31]]
# 0.8205128205128205
#               precision    recall  f1-score   support
#
#           -1       1.00      0.14      0.25         7
#            0       0.00      0.00      0.00         1
#            1       0.82      1.00      0.90        31
#
#     accuracy                           0.82        39
#    macro avg       0.61      0.38      0.38        39
# weighted avg       0.83      0.82      0.76        39
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##**Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
LRClassification=LogisticRegression()
LRClassification.fit(Xtrain_tf, Ytrain)
y_pred=LRClassification.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest, y_pred))
print(classification_report(Ytest, y_pred))
matrix = plot_confusion_matrix(LRClassification , Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Logistic Regression Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[ 1  0  6]
#  [ 0  0  1]
#  [ 0  0 31]]
# 0.8205128205128205
#               precision    recall  f1-score   support
#
#           -1       1.00      0.14      0.25         7
#            0       0.00      0.00      0.00         1
#            1       0.82      1.00      0.90        31
#
#     accuracy                           0.82        39
#    macro avg       0.61      0.38      0.38        39
# weighted avg       0.83      0.82      0.76        39
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##**Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
DTClassification=DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
DTClassification.fit(Xtrain_tf, Ytrain)
y_pred=DTClassification.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(DTClassification , Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Decision Tree Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[ 3  0  4]
#  [ 0  0  1]
#  [ 0  0 31]]
# 0.8717948717948718
#               precision    recall  f1-score   support
#
#           -1       1.00      0.43      0.60         7
#            0       0.00      0.00      0.00         1
#            1       0.86      1.00      0.93        31
#
#     accuracy                           0.87        39
#    macro avg       0.62      0.48      0.51        39
# weighted avg       0.86      0.87      0.84        39
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##**SVM**

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear') # Linear Kernel
#Train the model using the training sets
clf.fit(Xtrain_tf, Ytrain)
#Predict the response for test dataset
y_pred = clf.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(clf , Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for SVM Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[ 3  0  4]
#  [ 0  0  1]
#  [ 0  0 31]]
# 0.8717948717948718
#               precision    recall  f1-score   support
#
#           -1       1.00      0.43      0.60         7
#            0       0.00      0.00      0.00         1
#            1       0.86      1.00      0.93        31
#
#     accuracy                           0.87        39
#    macro avg       0.62      0.48      0.51        39
# weighted avg       0.86      0.87      0.84        39
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##**Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier=RandomForestClassifier(n_estimators=100, criterion ='entropy', random_state = 0).fit(Xtrain_tf, Ytrain)
y_pred=rf_classifier.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(rf_classifier, Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Random Forest Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[ 2  0  5]
#  [ 0  0  1]
#  [ 0  0 31]]
# 0.8461538461538461
#               precision    recall  f1-score   support
#
#           -1       1.00      0.29      0.44         7
#            0       0.00      0.00      0.00         1
#            1       0.84      1.00      0.91        31
#
#     accuracy                           0.85        39
#    macro avg       0.61      0.43      0.45        39
# weighted avg       0.85      0.85      0.80        39
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##**SGD**

# %%
from sklearn.linear_model import SGDClassifier
sgd_classifier = SGDClassifier(loss = 'log',penalty='l2', max_iter=10,random_state=0).fit(Xtrain_tf, Ytrain)
y_pred=sgd_classifier.predict(Xtest_tf)
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_stochastic_gradient.py:173: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(sgd_classifier, Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for SGD Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[ 3  0  4]
#  [ 1  0  0]
#  [ 0  0 31]]
# 0.8717948717948718
#               precision    recall  f1-score   support
#
#           -1       0.75      0.43      0.55         7
#            0       0.00      0.00      0.00         1
#            1       0.89      1.00      0.94        31
#
#     accuracy                           0.87        39
#    macro avg       0.55      0.48      0.49        39
# weighted avg       0.84      0.87      0.84        39
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##**RandomizedSearchCV**

# %%
svm_clf = svm.SVC(probability = True, random_state = 1)
auc = make_scorer(roc_auc_score)
 
# RANDOM SEARCH FOR 20 COMBINATIONS OF PARAMETERS
rand_list = {"C": stats.uniform(2, 10),
             "gamma": stats.uniform(0.1, 1),
             'kernel': ['rbf']}
              
rand_search = RandomizedSearchCV(svm_clf , param_distributions = rand_list, n_iter = 20, n_jobs = 4, cv = 3, random_state = 2017, scoring = auc) 
rand_search.fit(Xtrain_tf, Ytrain) 
rand_search.cv_results_
rand_predictions = rand_search.predict(Xtest_tf)
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
#   warnings.warn(

# %%
print(confusion_matrix(Ytest,rand_predictions))
print(accuracy_score(Ytest,rand_predictions))
print(classification_report(Ytest,rand_predictions))
matrix = plot_confusion_matrix(rand_search, Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Random Forest Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[ 3  0  4]
#  [ 0  0  1]
#  [ 0  0 31]]
# 0.8717948717948718
#               precision    recall  f1-score   support
#
#           -1       1.00      0.43      0.60         7
#            0       0.00      0.00      0.00         1
#            1       0.86      1.00      0.93        31
#
#     accuracy                           0.87        39
#    macro avg       0.62      0.48      0.51        39
# weighted avg       0.86      0.87      0.84        39
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
